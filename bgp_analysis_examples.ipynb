# %% [markdown]
# ## Real-time analysis

# %%
import time
import datetime
from collections import defaultdict
import ipaddress
from pybgpstream import BGPStream

# Define constants
COLLECTION_DURATION = 60  # 10 minutes in seconds
TARGET_ASN = '4766'

def process_update(stream):

    # Initialize counters and tracking variables
    announcements = defaultdict(int)
    withdrawals = defaultdict(int)
    prefix_as_paths = {}
    community_counts = defaultdict(int)
    med_values = []
    collector_to_prefix_count = defaultdict(int)

    # Start timer
    collection_start_time = time.time()
    interval_start_time = collection_start_time

    while True:
        # Check if the total collection duration has been exceeded
        if time.time() - collection_start_time >= COLLECTION_DURATION:
            break

        for rec in stream.records():
            for elem in rec:
                # Get timestamp and type
                elem_time = datetime.datetime.utcfromtimestamp(elem.time)
                elem_type = elem.type  # 'A' for announcements, 'W' for withdrawals

                # Fields dictionary
                fields = elem.fields

                # Prefix
                prefix = fields.get("prefix")
                if prefix is None:
                    continue

                # AS Path
                as_path_str = fields.get('as-path', "")
                as_path = as_path_str.split()

                # Peer ASN and Collector
                peer_asn = elem.peer_asn
                collector = rec.collector

                # Communities
                communities = fields.get('communities', [])

                # Validate and parse IP prefix
                try:
                    network = ipaddress.ip_network(prefix)
                except ValueError:
                    continue

                # Filtering logic within the loop
                # Filter for a specific ASN in AS Path
                if TARGET_ASN not in as_path:
                    continue

                # Counting announcements and withdrawals
                if elem_type == 'A':
                    announcements[prefix] += 1
                elif elem_type == 'W':
                    withdrawals[prefix] += 1

                # Detecting AS Path changes
                if prefix in prefix_as_paths:
                    if as_path!= prefix_as_paths[prefix]:
                        # AS path has changed
                        # Handle AS path change
                        prefix_as_paths[prefix] = as_path
                else:
                    prefix_as_paths[prefix] = as_path

                # Analyze community attributes
                for community in communities:
                    community_str = f"{community[0]}:{community[1]}"
                    community_counts[community_str] += 1

                # Calculate statistics (e.g., Average MED)
                med = fields.get('med')
                if med is not None:
                    try:
                        med_values.append(int(med))
                    except ValueError:
                        pass

                # Update collector-to-prefix count
                collector_to_prefix_count[collector] += 1

        # Print summary every minute
        current_time = time.time()
        if current_time - interval_start_time >= 60:
            print(f"Summary at {current_time}:")
            print(f"Unique Prefixes: {len(announcements)}")
            print(f"Origin ASes: {len(set(as_path for as_path in prefix_as_paths.values()))}")
            print(f"Collector-to-Prefix Count: {collector_to_prefix_count}")
            interval_start_time = current_time

def main():
    """
    Run the script.
    """
    stream = BGPStream(project="ris-live", record_type="updates")

    process_update(stream)

if __name__ == "__main__":
    main()

# %% [markdown]
# ## Updates Summary

# %%
import pybgpstream
from datetime import datetime, timezone
import os
import statistics
import re

def process_bgp_updates(directory, target_asn, from_time_str, until_time_str):
    # Parse the time window strings into datetime objects
    from_time = datetime.strptime(from_time_str, "%Y-%m-%d %H:%M:%S").replace(tzinfo=timezone.utc)
    until_time = datetime.strptime(until_time_str, "%Y-%m-%d %H:%M:%S").replace(tzinfo=timezone.utc)

    # Regular expression pattern to match filenames and extract timestamp
    pattern = r'^updates\.(\d{8})\.(\d{4})\.gz$'

    # List to store update counts
    update_counts = []

    # Iterate over each file in the specified directory
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith(".gz"):
                # Match the filename with the pattern
                match = re.match(pattern, file)
                if match:
                    date_str = match.group(1)  # YYYYMMDD
                    time_str = match.group(2)  # HHMM

                    # Combine date and time strings
                    file_timestamp_str = date_str + time_str

                    # Convert file timestamp to datetime object
                    file_time = datetime.strptime(file_timestamp_str, "%Y%m%d%H%M").replace(tzinfo=timezone.utc)

                    # Check if file time is within the desired time window
                    if file_time < from_time or file_time > until_time:
                        # Skip files outside the time window
                        continue

                    # Proceed to process the file
                    file_path = os.path.join(root, file)

                    # Initialize a new BGPStream instance for each file
                    stream = pybgpstream.BGPStream(data_interface="singlefile")

                    # Set the file for BGPStream to process
                    stream.set_data_interface_option("singlefile", "upd-file", file_path)

                    count = 0

                    for rec in stream.records():
                        for elem in rec:
                            # Get the element timestamp and set timezone to UTC
                            elem_time = datetime.utcfromtimestamp(elem.time).replace(tzinfo=timezone.utc)

                            # Filter elements outside the time window
                            if elem_time < from_time or elem_time > until_time:
                                continue

                            elem_type = elem.type  # 'A' for announcements, 'W' for withdrawals
                            fields = elem.fields
                            as_path = fields.get("as-path", "").split()

                            # Filter for target ASN in the AS path
                            if target_asn in as_path:
                                if elem_type in {'A', 'W'}:  # Count only announcements and withdrawals
                                    count += 1

                    # Store the count after processing each file
                    update_counts.append(count)
                else:
                    # If filename doesn't match pattern, skip it
                    continue

    # Calculate min, max, and median
    min_updates = min(update_counts) if update_counts else 0
    max_updates = max(update_counts) if update_counts else 0
    median_updates = statistics.median(update_counts) if update_counts else 0

    # Print the summary results
    print(f"Summary for AS{target_asn}:")
    print(f"Minimum updates: {min_updates}")
    print(f"Maximum updates: {max_updates}")
    print(f"Median updates: {median_updates}")

if __name__ == "__main__":
    # Define the directory and target ASN
    directory = "/home/hb/ris_bgp_updates/2024/10/rrc00"
    target_asn = "3356"  # Filter by specific ASN in AS path

    # Define the time window
    from_time_str = "2024-10-28 13:00:00"
    until_time_str = "2024-10-28 13:15:00"

    process_bgp_updates(directory, target_asn=target_asn, from_time_str=from_time_str, until_time_str=until_time_str)
# Out:
# Summary for AS3356:
# Minimum updates: 150
# Maximum updates: 58569
# Median updates: 29359.5

# %% [markdown]
# ## Unique prefixes

# %%
import pybgpstream
from datetime import datetime
from collections import defaultdict

def summarize_prefixes_and_origins():
    # Define the time range
    from_time = "2024-10-28 13:00:00"
    until_time = "2024-10-28 13:15:00"

    # Initialize BGPStream
    stream = pybgpstream.BGPStream(
        from_time=from_time,
        until_time=until_time,
        record_type="updates"
    )

    # Data structures to store unique prefixes and origin AS changes
    unique_prefixes = set()
    origin_as_changes = defaultdict(set)

    # Iterate over records and elements
    for rec in stream.records():
        for elem in rec:
            # Extract element information
            elem_type = elem.type  # 'A' for announcements, 'W' for withdrawals
            fields = elem.fields
            prefix = fields.get("prefix")
            if prefix is None:
                continue  # Skip elements without prefix information

            # Extract AS path and check if AS4766 is in the AS path
            as_path_str = fields.get('as-path', "")
            as_path = as_path_str.split()
            if '4766' not in as_path:
                continue  # Only process paths containing AS4766

            # Process announcements for tracking unique prefixes and origin AS changes
            if elem_type == 'A':
                unique_prefixes.add(prefix)  # Track unique prefixes

                # Track changes in origin AS for the prefix
                origin_as = as_path[-1] if as_path else None
                if origin_as:
                    origin_as_changes[prefix].add(origin_as)

    # Output summary
    print(f"Total unique prefixes associated with AS4766: {len(unique_prefixes)}")
    for prefix, origin_as_set in origin_as_changes.items():
        print(f"Prefix: {prefix}")
        print(f"  Origin AS count: {len(origin_as_set)}")
        if len(origin_as_set) > 1:
            print(f"  Changes in origin AS observed: {origin_as_set}")

if __name__ == "__main__":
    summarize_prefixes_and_origins()

# %%
import os
import re
import pybgpstream
from datetime import datetime, timezone
from collections import defaultdict, Counter
import statistics

def process_local_bgp_updates():
    # Define the time window and target ASN
    from_time_str = "2024-10-28 13:00:00"
    until_time_str = "2024-10-28 14:00:00"
    target_asn = "4766"

    # Parse the time strings into timezone-aware datetime objects
    from_time = datetime.strptime(from_time_str, "%Y-%m-%d %H:%M:%S").replace(tzinfo=timezone.utc)
    until_time = datetime.strptime(until_time_str, "%Y-%m-%d %H:%M:%S").replace(tzinfo=timezone.utc)

    # The directory containing BGP update files
    directory = "/home/hb/ris_bgp_updates/2024/10/rrc00"

    # Regex pattern to match filenames: updates.YYYYMMDD.HHMM.gz
    pattern = r'^updates\.(\d{8})\.(\d{4})\.(bz2|gz)$'

    # Data structures:
    #  - unique_prefixes stores each prefix encountered for a relevant announcement
    #  - origin_as_changes tracks a set of origin ASNs (for potential MOAS detection)
    unique_prefixes = set()
    origin_as_changes = defaultdict(set)

    # Traverse the directory and filter files by time window
    for root, _, files in os.walk(directory):
        for file in files:
            match = re.match(pattern, file)
            if match:
                date_str = match.group(1)  # YYYYMMDD
                time_str = match.group(2)  # HHMM

                # Convert the extracted date/time to a datetime object
                file_timestamp_str = date_str + time_str  # e.g., "20241028" + "1300" = "202410281300"
                file_time = datetime.strptime(file_timestamp_str, "%Y%m%d%H%M").replace(tzinfo=timezone.utc)

                # Check if file time is within the specified time window
                if file_time < from_time or file_time > until_time:
                    continue

                file_path = os.path.join(root, file)

                # Initialize BGPStream for local file processing
                stream = pybgpstream.BGPStream(data_interface="singlefile")
                stream.set_data_interface_option("singlefile", "upd-file", file_path)

                # Process each record and element in the file
                for rec in stream.records():
                    for elem in rec:
                        elem_time = datetime.utcfromtimestamp(elem.time).replace(tzinfo=timezone.utc)
                        if elem_time < from_time or elem_time > until_time:
                            continue

                        elem_type = elem.type  # 'A' for announcements, 'W' for withdrawals
                        fields = elem.fields
                        prefix = fields.get("prefix")
                        if prefix is None:
                            continue

                        # Check the as-path
                        as_path_str = fields.get('as-path', "")
                        as_path = as_path_str.split()

                        # Filter for target ASN in the AS path
                        # Remove if you want to detect MOAS conflicts regardless of target ASN
                        if target_asn not in as_path:
                            continue

                        # We only track announcements
                        if elem_type == 'A':
                            unique_prefixes.add(prefix)
                            origin_asn = as_path[-1] if as_path else None
                            if origin_asn:
                                origin_as_changes[prefix].add(origin_asn)

    # Print results
    print(f"Total unique prefixes associated with AS{target_asn}: {len(unique_prefixes)}")
    for prefix, origin_set in origin_as_changes.items():
        print(f"Prefix: {prefix}")
        print(f"  Origin AS count: {len(origin_set)}")
        if len(origin_set) > 1:
            print(f"  MOAS conflict observed: {origin_set}")

if __name__ == "__main__":
    process_local_bgp_updates()
# Out:
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1400.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1330.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1345.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1315.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1300.gz
# Total unique prefixes associated with AS4766: 616
# Prefix: 14.129.75.0/24
#   Origin AS count: 1
# Prefix: 14.129.73.0/24
#   Origin AS count: 1
# Prefix: 14.129.74.0/24
#   Origin AS count: 1
# Prefix: 14.129.76.0/24
#   Origin AS count: 1
# Prefix: 211.156.223.0/24
#   Origin AS count: 1
# Prefix: 211.156.221.0/24
#   Origin AS count: 1
# Prefix: 211.156.220.0/24
#   Origin AS count: 1
# Prefix: 211.156.219.0/24
#   Origin AS count: 1
# Prefix: 211.156.218.0/24
#   Origin AS count: 1
# Prefix: 211.156.217.0/24
#   Origin AS count: 1
# Prefix: 211.156.216.0/24
#   Origin AS count: 1
# Prefix: 211.156.215.0/24
#   Origin AS count: 1
# Prefix: 211.156.214.0/24
#   Origin AS count: 1
# Prefix: 211.156.213.0/24
#   Origin AS count: 1
# Prefix: 211.156.212.0/24
#   Origin AS count: 1
# Prefix: 211.156.211.0/24
#   Origin AS count: 1
# Prefix: 211.156.210.0/24
#   Origin AS count: 1
# Prefix: 211.156.209.0/24
#   Origin AS count: 1
# Prefix: 211.156.208.0/24
#   Origin AS count: 1
# Prefix: 211.156.207.0/24
#   Origin AS count: 1
# Prefix: 211.156.206.0/24
#   Origin AS count: 1
# Prefix: 211.156.205.0/24
#   Origin AS count: 1
# Prefix: 211.156.204.0/24
#   Origin AS count: 1
# Prefix: 211.156.203.0/24
#   Origin AS count: 1
# Prefix: 211.156.202.0/24
#   Origin AS count: 1
# Prefix: 211.156.201.0/24
#   Origin AS count: 1
# Prefix: 211.156.200.0/24
#   Origin AS count: 1
# Prefix: 211.156.199.0/24
#   Origin AS count: 1
# Prefix: 211.156.198.0/24
#   Origin AS count: 1
# Prefix: 211.156.197.0/24
#   Origin AS count: 1
# Prefix: 211.156.196.0/24
#   Origin AS count: 1
# Prefix: 211.156.195.0/24
#   Origin AS count: 1
# Prefix: 211.156.194.0/24
#   Origin AS count: 1
# Prefix: 211.156.193.0/24
#   Origin AS count: 1
# Prefix: 211.156.192.0/24
#   Origin AS count: 1
# Prefix: 120.72.190.0/24
#   Origin AS count: 1
# Prefix: 120.72.189.0/24
#   Origin AS count: 1
# Prefix: 120.72.188.0/24
#   Origin AS count: 1
# Prefix: 120.72.187.0/24
#   Origin AS count: 1
# Prefix: 120.72.186.0/24
#   Origin AS count: 1
# Prefix: 120.72.185.0/24
#   Origin AS count: 1
# Prefix: 120.72.184.0/24
#   Origin AS count: 1
# Prefix: 120.72.182.0/24
#   Origin AS count: 1
# Prefix: 120.72.180.0/24
#   Origin AS count: 1
# Prefix: 120.72.178.0/24
#   Origin AS count: 1
# Prefix: 120.72.177.0/24
#   Origin AS count: 1
# Prefix: 120.72.173.0/24
#   Origin AS count: 1
# Prefix: 120.72.172.0/24
#   Origin AS count: 1
# Prefix: 120.72.171.0/24
#   Origin AS count: 1
# Prefix: 120.72.170.0/24
#   Origin AS count: 1
# Prefix: 120.72.168.0/24
#   Origin AS count: 1
# Prefix: 120.72.167.0/24
#   Origin AS count: 1
# Prefix: 120.72.166.0/24
#   Origin AS count: 1
# Prefix: 120.72.163.0/24
#   Origin AS count: 1
# Prefix: 120.72.162.0/24
#   Origin AS count: 1
# Prefix: 120.72.160.0/24
#   Origin AS count: 1
# Prefix: 14.55.70.0/23
#   Origin AS count: 1
# Prefix: 14.55.72.0/23
#   Origin AS count: 1
# Prefix: 1.34.184.0/24
#   Origin AS count: 1
# Prefix: 211.52.3.0/24
#   Origin AS count: 1
# Prefix: 220.67.208.0/24
#   Origin AS count: 1
# Prefix: 220.69.200.0/24
#   Origin AS count: 1
# Prefix: 220.95.160.0/20
#   Origin AS count: 1
# Prefix: 211.104.115.0/24
#   Origin AS count: 1
# Prefix: 168.126.80.0/24
#   Origin AS count: 1
# Prefix: 218.146.146.0/24
#   Origin AS count: 1
# Prefix: 14.206.54.0/24
#   Origin AS count: 1
# Prefix: 101.250.141.0/24
#   Origin AS count: 1
# Prefix: 117.16.52.0/23
#   Origin AS count: 1
# Prefix: 211.52.2.0/24
#   Origin AS count: 1
# Prefix: 220.67.209.0/24
#   Origin AS count: 1
# Prefix: 220.69.201.0/24
#   Origin AS count: 1
# Prefix: 101.101.240.0/21
#   Origin AS count: 1
# Prefix: 183.106.30.0/24
#   Origin AS count: 1
# Prefix: 117.111.200.0/24
#   Origin AS count: 1
# Prefix: 121.126.128.0/17
#   Origin AS count: 1
# Prefix: 203.237.126.0/24
#   Origin AS count: 1
# Prefix: 101.250.140.0/24
#   Origin AS count: 1
# Prefix: 182.31.200.0/21
#   Origin AS count: 1
# Prefix: 14.50.196.0/22
#   Origin AS count: 1
# Prefix: 220.67.210.0/24
#   Origin AS count: 1
# Prefix: 220.69.202.0/24
#   Origin AS count: 1
# Prefix: 183.106.29.0/24
#   Origin AS count: 1
# Prefix: 222.118.4.0/24
#   Origin AS count: 1
# Prefix: 168.126.82.0/24
#   Origin AS count: 1
# Prefix: 121.137.95.0/24
#   Origin AS count: 1
# Prefix: 218.146.144.0/24
#   Origin AS count: 1
# Prefix: 202.160.72.0/21
#   Origin AS count: 1
# Prefix: 203.237.125.0/24
#   Origin AS count: 1
# Prefix: 101.250.143.0/24
#   Origin AS count: 1
# Prefix: 211.52.0.0/18
#   Origin AS count: 1
# Prefix: 220.67.211.0/24
#   Origin AS count: 1
# Prefix: 220.69.203.0/24
#   Origin AS count: 1
# Prefix: 115.92.0.0/24
#   Origin AS count: 1
# Prefix: 183.106.28.0/24
#   Origin AS count: 1
# Prefix: 121.137.94.0/24
#   Origin AS count: 1
# Prefix: 218.146.145.0/24
#   Origin AS count: 1
# Prefix: 221.162.86.0/24
#   Origin AS count: 1
# Prefix: 203.230.80.0/20
#   Origin AS count: 1
# Prefix: 203.236.120.0/24
#   Origin AS count: 1
# Prefix: 203.237.124.0/24
#   Origin AS count: 1
# Prefix: 101.250.142.0/24
#   Origin AS count: 1
# Prefix: 211.251.60.0/22
#   Origin AS count: 1
# Prefix: 211.52.7.0/24
#   Origin AS count: 1
# Prefix: 220.67.212.0/24
#   Origin AS count: 1
# Prefix: 220.69.204.0/24
#   Origin AS count: 1
# Prefix: 121.137.89.0/24
#   Origin AS count: 1
# Prefix: 203.237.123.0/24
#   Origin AS count: 1
# Prefix: 101.250.137.0/24
#   Origin AS count: 1
# Prefix: 211.52.6.0/24
#   Origin AS count: 1
# Prefix: 220.67.213.0/24
#   Origin AS count: 1
# Prefix: 220.69.205.0/24
#   Origin AS count: 1
# Prefix: 121.136.92.0/24
#   Origin AS count: 1
# Prefix: 121.137.88.0/24
#   Origin AS count: 1
# Prefix: 211.170.126.0/24
#   Origin AS count: 1
# Prefix: 121.186.148.0/24
#   Origin AS count: 1
# Prefix: 203.237.122.0/24
#   Origin AS count: 1
# Prefix: 101.250.136.0/24
#   Origin AS count: 1
# Prefix: 14.50.192.0/21
#   Origin AS count: 1
# Prefix: 14.50.192.0/22
#   Origin AS count: 1
# Prefix: 211.52.5.0/24
#   Origin AS count: 1
# Prefix: 211.55.9.0/24
#   Origin AS count: 1
# Prefix: 220.67.214.0/24
#   Origin AS count: 1
# Prefix: 220.69.206.0/24
#   Origin AS count: 1
# Prefix: 210.97.80.0/24
#   Origin AS count: 1
# Prefix: 210.101.64.0/18
#   Origin AS count: 1
# Prefix: 121.150.39.0/24
#   Origin AS count: 1
# Prefix: 218.151.128.0/17
#   Origin AS count: 1
# Prefix: 203.237.121.0/24
#   Origin AS count: 1
# Prefix: 101.250.139.0/24
#   Origin AS count: 1
# Prefix: 211.52.4.0/24
#   Origin AS count: 1
# Prefix: 220.67.215.0/24
#   Origin AS count: 1
# Prefix: 220.69.207.0/24
#   Origin AS count: 1
# Prefix: 61.106.146.0/24
#   Origin AS count: 1
# Prefix: 39.126.216.0/21
#   Origin AS count: 1
# Prefix: 121.137.90.0/24
#   Origin AS count: 1
# Prefix: 211.216.180.0/22
#   Origin AS count: 1
# Prefix: 203.237.120.0/24
#   Origin AS count: 1
# Prefix: 203.243.0.0/18
#   Origin AS count: 1
# Prefix: 101.250.138.0/24
#   Origin AS count: 1
# Prefix: 211.251.56.0/22
#   Origin AS count: 1
# Prefix: 211.252.36.0/24
#   Origin AS count: 1
# Prefix: 211.253.32.0/24
#   Origin AS count: 1
# Prefix: 117.16.61.0/24
#   Origin AS count: 1
# Prefix: 61.34.189.0/24
#   Origin AS count: 1
# Prefix: 211.39.71.0/24
#   Origin AS count: 1
# Prefix: 211.52.11.0/24
#   Origin AS count: 1
# Prefix: 220.67.216.0/24
#   Origin AS count: 1
# Prefix: 220.69.192.0/24
#   Origin AS count: 1
# Prefix: 110.92.22.0/24
#   Origin AS count: 1
# Prefix: 210.110.98.0/24
#   Origin AS count: 1
# Prefix: 221.164.69.0/24
#   Origin AS count: 1
# Prefix: 113.198.97.0/24
#   Origin AS count: 1
# Prefix: 203.237.119.0/24
#   Origin AS count: 1
# Prefix: 101.250.133.0/24
#   Origin AS count: 1
# Prefix: 117.16.60.0/24
#   Origin AS count: 1
# Prefix: 211.39.70.0/24
#   Origin AS count: 1
# Prefix: 211.52.10.0/24
#   Origin AS count: 1
# Prefix: 220.67.217.0/24
#   Origin AS count: 1
# Prefix: 220.69.193.0/24
#   Origin AS count: 1
# Prefix: 210.110.99.0/24
#   Origin AS count: 1
# Prefix: 39.126.214.0/23
#   Origin AS count: 1
# Prefix: 220.126.45.0/24
#   Origin AS count: 1
# Prefix: 121.157.4.0/24
#   Origin AS count: 1
# Prefix: 221.164.68.0/24
#   Origin AS count: 1
# Prefix: 113.198.96.0/24
#   Origin AS count: 1
# Prefix: 203.237.118.0/24
#   Origin AS count: 1
# Prefix: 101.250.132.0/24
#   Origin AS count: 1
# Prefix: 117.16.63.0/24
#   Origin AS count: 1
# Prefix: 115.22.33.0/24
#   Origin AS count: 1
# Prefix: 14.63.248.0/23
#   Origin AS count: 1
# Prefix: 220.66.222.0/24
#   Origin AS count: 1
# Prefix: 220.67.218.0/24
#   Origin AS count: 1
# Prefix: 220.69.194.0/24
#   Origin AS count: 1
# Prefix: 210.110.96.0/24
#   Origin AS count: 1
# Prefix: 121.137.87.0/24
#   Origin AS count: 1
# Prefix: 221.164.71.0/24
#   Origin AS count: 1
# Prefix: 113.198.99.0/24
#   Origin AS count: 1
# Prefix: 211.223.165.0/24
#   Origin AS count: 1
# Prefix: 203.237.117.0/24
#   Origin AS count: 1
# Prefix: 101.250.135.0/24
#   Origin AS count: 1
# Prefix: 147.6.128.0/17
#   Origin AS count: 1
# Prefix: 117.16.62.0/24
#   Origin AS count: 1
# Prefix: 115.22.32.0/24
#   Origin AS count: 1
# Prefix: 220.66.223.0/24
#   Origin AS count: 1
# Prefix: 220.67.219.0/24
#   Origin AS count: 1
# Prefix: 220.69.195.0/24
#   Origin AS count: 1
# Prefix: 110.92.21.0/24
#   Origin AS count: 1
# Prefix: 210.110.97.0/24
#   Origin AS count: 1
# Prefix: 222.121.49.0/24
#   Origin AS count: 1
# Prefix: 115.144.56.0/24
#   Origin AS count: 1
# Prefix: 180.150.231.0/24
#   Origin AS count: 1
# Prefix: 221.164.70.0/24
#   Origin AS count: 1
# Prefix: 113.198.98.0/24
#   Origin AS count: 1
# Prefix: 211.222.160.0/24
#   Origin AS count: 1
# Prefix: 211.223.164.0/24
#   Origin AS count: 1
# Prefix: 203.237.116.0/24
#   Origin AS count: 1
# Prefix: 211.246.0.0/17
#   Origin AS count: 1
# Prefix: 101.250.134.0/24
#   Origin AS count: 1
# Prefix: 211.251.52.0/22
#   Origin AS count: 1
# Prefix: 220.67.220.0/24
#   Origin AS count: 1
# Prefix: 220.69.196.0/24
#   Origin AS count: 1
# Prefix: 220.71.204.0/24
#   Origin AS count: 1
# Prefix: 210.110.102.0/24
#   Origin AS count: 1
# Prefix: 220.116.0.0/14
#   Origin AS count: 1
# Prefix: 175.195.175.0/24
#   Origin AS count: 1
# Prefix: 203.237.115.0/24
#   Origin AS count: 1
# Prefix: 101.250.129.0/24
#   Origin AS count: 1
# Prefix: 220.67.221.0/24
#   Origin AS count: 1
# Prefix: 220.69.197.0/24
#   Origin AS count: 1
# Prefix: 125.140.64.0/24
#   Origin AS count: 1
# Prefix: 125.140.64.0/18
#   Origin AS count: 1
# Prefix: 180.150.225.0/24
#   Origin AS count: 1
# Prefix: 121.157.0.0/22
#   Origin AS count: 1
# Prefix: 203.237.114.0/24
#   Origin AS count: 1
# Prefix: 125.243.188.0/24
#   Origin AS count: 1
# Prefix: 101.250.128.0/24
#   Origin AS count: 1
# Prefix: 211.253.42.0/24
#   Origin AS count: 1
# Prefix: 14.50.200.0/21
#   Origin AS count: 1
# Prefix: 220.67.222.0/24
#   Origin AS count: 1
# Prefix: 220.69.198.0/24
#   Origin AS count: 1
# Prefix: 58.103.168.0/23
#   Origin AS count: 1
# Prefix: 210.110.100.0/24
#   Origin AS count: 1
# Prefix: 180.150.226.0/24
#   Origin AS count: 1
# Prefix: 203.237.113.0/24
#   Origin AS count: 1
# Prefix: 101.250.131.0/24
#   Origin AS count: 1
# Prefix: 211.253.41.0/24
#   Origin AS count: 1
# Prefix: 220.67.223.0/24
#   Origin AS count: 1
# Prefix: 220.69.199.0/24
#   Origin AS count: 1
# Prefix: 183.78.128.0/20
#   Origin AS count: 1
# Prefix: 210.99.81.0/24
#   Origin AS count: 1
# Prefix: 210.110.101.0/24
#   Origin AS count: 1
# Prefix: 121.126.142.0/24
#   Origin AS count: 1
# Prefix: 125.140.66.0/24
#   Origin AS count: 1
# Prefix: 118.128.121.0/24
#   Origin AS count: 1
# Prefix: 180.150.227.0/24
#   Origin AS count: 1
# Prefix: 211.175.96.0/23
#   Origin AS count: 1
# Prefix: 203.237.112.0/24
#   Origin AS count: 1
# Prefix: 101.250.130.0/24
#   Origin AS count: 1
# Prefix: 211.251.48.0/22
#   Origin AS count: 1
# Prefix: 218.48.10.0/24
#   Origin AS count: 1
# Prefix: 211.52.19.0/24
#   Origin AS count: 1
# Prefix: 220.67.192.0/24
#   Origin AS count: 1
# Prefix: 220.69.216.0/21
#   Origin AS count: 1
# Prefix: 220.73.232.0/24
#   Origin AS count: 1
# Prefix: 220.95.176.0/20
#   Origin AS count: 1
# Prefix: 115.144.35.0/24
#   Origin AS count: 1
# Prefix: 220.149.152.0/24
#   Origin AS count: 1
# Prefix: 121.191.149.0/24
#   Origin AS count: 1
# Prefix: 203.237.111.0/24
#   Origin AS count: 1
# Prefix: 101.250.157.0/24
#   Origin AS count: 1
# Prefix: 211.52.18.0/24
#   Origin AS count: 1
# Prefix: 220.67.193.0/24
#   Origin AS count: 1
# Prefix: 220.73.233.0/24
#   Origin AS count: 1
# Prefix: 61.97.168.0/21
#   Origin AS count: 1
# Prefix: 101.101.224.0/22
#   Origin AS count: 1
# Prefix: 165.141.128.0/19
#   Origin AS count: 1
# Prefix: 220.149.153.0/24
#   Origin AS count: 1
# Prefix: 203.237.110.0/24
#   Origin AS count: 1
# Prefix: 101.250.156.0/24
#   Origin AS count: 1
# Prefix: 182.31.216.0/21
#   Origin AS count: 1
# Prefix: 211.52.17.0/24
#   Origin AS count: 1
# Prefix: 220.67.194.0/24
#   Origin AS count: 1
# Prefix: 220.73.234.0/24
#   Origin AS count: 1
# Prefix: 220.90.166.0/24
#   Origin AS count: 1
# Prefix: 220.149.154.0/24
#   Origin AS count: 1
# Prefix: 218.152.168.0/24
#   Origin AS count: 1
# Prefix: 121.191.151.0/24
#   Origin AS count: 1
# Prefix: 203.237.109.0/24
#   Origin AS count: 1
# Prefix: 101.250.159.0/24
#   Origin AS count: 1
# Prefix: 59.18.96.0/19
#   Origin AS count: 1
# Prefix: 211.48.0.0/16
#   Origin AS count: 1
# Prefix: 211.56.32.0/19
#   Origin AS count: 1
# Prefix: 220.67.195.0/24
#   Origin AS count: 1
# Prefix: 220.73.235.0/24
#   Origin AS count: 1
# Prefix: 27.96.136.0/21
#   Origin AS count: 1
# Prefix: 39.126.204.0/23
#   Origin AS count: 1
# Prefix: 121.133.126.0/24
#   Origin AS count: 1
# Prefix: 220.149.155.0/24
#   Origin AS count: 1
# Prefix: 121.150.50.0/24
#   Origin AS count: 1
# Prefix: 182.172.21.0/24
#   Origin AS count: 1
# Prefix: 121.191.150.0/24
#   Origin AS count: 1
# Prefix: 203.234.112.0/22
#   Origin AS count: 1
# Prefix: 203.235.116.0/24
#   Origin AS count: 1
# Prefix: 203.237.108.0/24
#   Origin AS count: 1
# Prefix: 203.246.0.0/17
#   Origin AS count: 1
# Prefix: 101.250.158.0/24
#   Origin AS count: 1
# Prefix: 211.251.44.0/22
#   Origin AS count: 1
# Prefix: 117.16.33.0/24
#   Origin AS count: 1
# Prefix: 211.52.23.0/24
#   Origin AS count: 1
# Prefix: 220.66.192.0/22
#   Origin AS count: 1
# Prefix: 220.67.196.0/24
#   Origin AS count: 1
# Prefix: 220.73.236.0/24
#   Origin AS count: 1
# Prefix: 61.84.121.0/24
#   Origin AS count: 1
# Prefix: 168.115.112.0/20
#   Origin AS count: 1
# Prefix: 115.144.39.0/24
#   Origin AS count: 1
# Prefix: 203.237.107.0/24
#   Origin AS count: 1
# Prefix: 101.250.153.0/24
#   Origin AS count: 1
# Prefix: 117.16.32.0/24
#   Origin AS count: 1
# Prefix: 211.52.22.0/24
#   Origin AS count: 1
# Prefix: 220.67.197.0/24
#   Origin AS count: 1
# Prefix: 210.99.75.0/24
#   Origin AS count: 1
# Prefix: 61.106.128.0/18
#   Origin AS count: 1
# Prefix: 1.231.136.0/24
#   Origin AS count: 1
# Prefix: 203.237.106.0/24
#   Origin AS count: 1
# Prefix: 101.250.152.0/24
#   Origin AS count: 1
# Prefix: 211.52.21.0/24
#   Origin AS count: 1
# Prefix: 220.67.198.0/24
#   Origin AS count: 1
# Prefix: 211.106.109.0/24
#   Origin AS count: 1
# Prefix: 203.237.105.0/24
#   Origin AS count: 1
# Prefix: 101.250.155.0/24
#   Origin AS count: 1
# Prefix: 117.16.34.0/24
#   Origin AS count: 1
# Prefix: 211.35.72.0/21
#   Origin AS count: 1
# Prefix: 211.52.20.0/24
#   Origin AS count: 1
# Prefix: 220.67.199.0/24
#   Origin AS count: 1
# Prefix: 103.68.96.0/24
#   Origin AS count: 1
# Prefix: 211.113.0.0/17
#   Origin AS count: 1
# Prefix: 39.126.200.0/22
#   Origin AS count: 1
# Prefix: 49.142.30.0/23
#   Origin AS count: 1
# Prefix: 220.149.159.0/24
#   Origin AS count: 1
# Prefix: 210.183.25.0/24
#   Origin AS count: 1
# Prefix: 211.193.192.0/21
#   Origin AS count: 1
# Prefix: 203.237.104.0/24
#   Origin AS count: 1
# Prefix: 101.250.154.0/24
#   Origin AS count: 1
# Prefix: 211.251.40.0/22
#   Origin AS count: 1
# Prefix: 211.253.48.0/21
#   Origin AS count: 1
# Prefix: 211.52.27.0/24
#   Origin AS count: 1
# Prefix: 220.67.200.0/24
#   Origin AS count: 1
# Prefix: 220.69.208.0/24
#   Origin AS count: 1
# Prefix: 203.237.103.0/24
#   Origin AS count: 1
# Prefix: 101.250.149.0/24
#   Origin AS count: 1
# Prefix: 211.52.26.0/24
#   Origin AS count: 1
# Prefix: 14.63.235.0/24
#   Origin AS count: 1
# Prefix: 220.67.201.0/24
#   Origin AS count: 1
# Prefix: 220.69.209.0/24
#   Origin AS count: 1
# Prefix: 61.97.160.0/21
#   Origin AS count: 1
# Prefix: 61.106.140.0/24
#   Origin AS count: 1
# Prefix: 221.150.156.0/23
#   Origin AS count: 1
# Prefix: 121.152.0.0/13
#   Origin AS count: 1
# Prefix: 175.192.182.0/24
#   Origin AS count: 1
# Prefix: 211.198.210.0/24
#   Origin AS count: 1
# Prefix: 43.228.162.0/23
#   Origin AS count: 1
# Prefix: 101.250.148.0/24
#   Origin AS count: 1
# Prefix: 182.31.208.0/21
#   Origin AS count: 1
# Prefix: 211.52.25.0/24
#   Origin AS count: 1
# Prefix: 220.67.202.0/24
#   Origin AS count: 1
# Prefix: 220.69.210.0/24
#   Origin AS count: 1
# Prefix: 210.105.108.0/24
#   Origin AS count: 1
# Prefix: 221.159.187.0/24
#   Origin AS count: 1
# Prefix: 210.178.0.0/16
#   Origin AS count: 1
# Prefix: 175.192.181.0/24
#   Origin AS count: 1
# Prefix: 203.237.101.0/24
#   Origin AS count: 1
# Prefix: 101.250.151.0/24
#   Origin AS count: 1
# Prefix: 59.8.0.0/13
#   Origin AS count: 1
# Prefix: 59.8.0.0/24
#   Origin AS count: 1
# Prefix: 59.25.68.0/24
#   Origin AS count: 1
# Prefix: 211.52.24.0/24
#   Origin AS count: 1
# Prefix: 220.67.203.0/24
#   Origin AS count: 1
# Prefix: 220.69.211.0/24
#   Origin AS count: 1
# Prefix: 39.126.196.0/22
#   Origin AS count: 1
# Prefix: 221.159.186.0/24
#   Origin AS count: 1
# Prefix: 43.228.160.0/23
#   Origin AS count: 1
# Prefix: 203.237.100.0/24
#   Origin AS count: 1
# Prefix: 101.250.150.0/24
#   Origin AS count: 1
# Prefix: 59.25.67.0/24
#   Origin AS count: 1
# Prefix: 220.67.204.0/24
#   Origin AS count: 1
# Prefix: 220.69.212.0/24
#   Origin AS count: 1
# Prefix: 39.126.195.0/24
#   Origin AS count: 1
# Prefix: 218.154.174.0/24
#   Origin AS count: 1
# Prefix: 101.250.145.0/24
#   Origin AS count: 1
# Prefix: 211.253.59.0/24
#   Origin AS count: 1
# Prefix: 59.25.66.0/24
#   Origin AS count: 1
# Prefix: 220.67.205.0/24
#   Origin AS count: 1
# Prefix: 220.69.213.0/24
#   Origin AS count: 1
# Prefix: 61.72.0.0/13
#   Origin AS count: 1
# Prefix: 210.96.79.0/24
#   Origin AS count: 1
# Prefix: 218.154.175.0/24
#   Origin AS count: 1
# Prefix: 121.191.152.0/24
#   Origin AS count: 1
# Prefix: 210.204.255.0/24
#   Origin AS count: 1
# Prefix: 211.225.74.0/24
#   Origin AS count: 1
# Prefix: 14.63.236.0/22
#   Origin AS count: 1
# Prefix: 222.112.0.0/13
#   Origin AS count: 1
# Prefix: 210.179.0.0/16
#   Origin AS count: 1
# Prefix: 203.225.81.0/24
#   Origin AS count: 1
# Prefix: 168.248.86.0/24
#   Origin AS count: 1
# Prefix: 211.51.0.0/16
#   Origin AS count: 1
# Prefix: 183.78.144.0/20
#   Origin AS count: 1
# Prefix: 222.121.37.0/24
#   Origin AS count: 1
# Prefix: 218.154.173.0/24
#   Origin AS count: 1
# Prefix: 211.253.56.0/24
#   Origin AS count: 1
# Prefix: 61.106.181.0/24
#   Origin AS count: 1
# Prefix: 210.110.74.0/24
#   Origin AS count: 1
# Prefix: 125.137.121.0/24
#   Origin AS count: 1
# Prefix: 203.249.15.0/24
#   Origin AS count: 1
# Prefix: 203.253.31.0/24
#   Origin AS count: 1
# Prefix: 117.17.16.0/20
#   Origin AS count: 1
# Prefix: 61.106.180.0/24
#   Origin AS count: 1
# Prefix: 210.110.75.0/24
#   Origin AS count: 1
# Prefix: 121.159.36.0/22
#   Origin AS count: 1
# Prefix: 203.234.66.0/24
#   Origin AS count: 1
# Prefix: 203.249.14.0/24
#   Origin AS count: 1
# Prefix: 211.46.73.0/24
#   Origin AS count: 1
# Prefix: 211.52.33.0/24
#   Origin AS count: 1
# Prefix: 210.97.116.0/24
#   Origin AS count: 1
# Prefix: 210.104.80.0/24
#   Origin AS count: 1
# Prefix: 61.106.183.0/24
#   Origin AS count: 1
# Prefix: 210.110.72.0/24
#   Origin AS count: 1
# Prefix: 119.194.93.0/24
#   Origin AS count: 1
# Prefix: 203.249.13.0/24
#   Origin AS count: 1
# Prefix: 211.253.5.0/24
#   Origin AS count: 1
# Prefix: 115.20.0.0/17
#   Origin AS count: 1
# Prefix: 61.106.182.0/24
#   Origin AS count: 1
# Prefix: 210.110.73.0/24
#   Origin AS count: 1
# Prefix: 125.137.122.0/24
#   Origin AS count: 1
# Prefix: 221.159.130.0/24
#   Origin AS count: 1
# Prefix: 211.188.0.0/20
#   Origin AS count: 1
# Prefix: 121.191.166.0/24
#   Origin AS count: 1
# Prefix: 203.249.12.0/24
#   Origin AS count: 1
# Prefix: 211.252.0.0/15
#   Origin AS count: 1
# Prefix: 59.18.87.0/24
#   Origin AS count: 1
# Prefix: 220.90.144.0/21
#   Origin AS count: 1
# Prefix: 61.106.177.0/24
#   Origin AS count: 1
# Prefix: 210.110.78.0/24
#   Origin AS count: 1
# Prefix: 124.198.64.0/18
#   Origin AS count: 1
# Prefix: 203.249.11.0/24
#   Origin AS count: 1
# Prefix: 39.126.194.0/24
#   Origin AS count: 1
# Prefix: 39.126.192.0/23
#   Origin AS count: 1
# Prefix: 49.143.45.0/24
#   Origin AS count: 1
# Prefix: 49.143.44.0/24
#   Origin AS count: 1
# Prefix: 49.143.47.0/24
#   Origin AS count: 1
# Prefix: 49.143.46.0/24
#   Origin AS count: 1
# Prefix: 121.170.204.0/24
#   Origin AS count: 1
# Prefix: 203.237.98.0/24
#   Origin AS count: 1
# Prefix: 220.67.206.0/24
#   Origin AS count: 1
# Prefix: 203.237.97.0/24
#   Origin AS count: 1
# Prefix: 220.67.207.0/24
#   Origin AS count: 1
# Prefix: 203.237.96.0/24
#   Origin AS count: 1
# Prefix: 117.16.16.0/20
#   Origin AS count: 1
# Prefix: 117.16.16.0/24
#   Origin AS count: 1
# Prefix: 101.250.144.0/24
#   Origin AS count: 1
# Prefix: 101.250.147.0/24
#   Origin AS count: 1
# Prefix: 175.207.140.0/24
#   Origin AS count: 1
# Prefix: 101.250.146.0/24
#   Origin AS count: 1
# Prefix: 101.250.173.0/24
#   Origin AS count: 1
# Prefix: 101.250.172.0/24
#   Origin AS count: 1
# Prefix: 101.250.175.0/24
#   Origin AS count: 1
# Prefix: 101.250.174.0/24
#   Origin AS count: 1
# Prefix: 101.250.169.0/24
#   Origin AS count: 1
# Prefix: 59.25.65.0/24
#   Origin AS count: 1
# Prefix: 59.25.64.0/24
#   Origin AS count: 1
# Prefix: 220.73.230.0/24
#   Origin AS count: 1
# Prefix: 220.73.231.0/24
#   Origin AS count: 1
# Prefix: 115.88.13.0/24
#   Origin AS count: 1
# Prefix: 183.109.29.0/24
#   Origin AS count: 1
# Prefix: 103.122.145.0/24
#   Origin AS count: 1
# Prefix: 203.235.121.0/24
#   Origin AS count: 1
# Prefix: 218.48.5.0/24
#   Origin AS count: 1
# Prefix: 220.66.244.0/24
#   Origin AS count: 1
# Prefix: 220.66.247.0/24
#   Origin AS count: 1
# Prefix: 1.231.185.0/24
#   Origin AS count: 1
# Prefix: 211.193.200.0/21
#   Origin AS count: 1
# Prefix: 61.83.85.0/24
#   Origin AS count: 1
# Prefix: 14.49.234.0/24
#   Origin AS count: 1
# Prefix: 14.49.235.0/24
#   Origin AS count: 1
# Prefix: 14.49.232.0/24
#   Origin AS count: 1
# Prefix: 14.49.233.0/24
#   Origin AS count: 1
# Prefix: 61.73.57.0/24
#   Origin AS count: 1
# Prefix: 218.145.190.0/24
#   Origin AS count: 1
# Prefix: 218.154.146.0/23
#   Origin AS count: 1
# Prefix: 218.154.144.0/23
#   Origin AS count: 1
# Prefix: 121.184.185.0/24
#   Origin AS count: 1
# Prefix: 121.184.184.0/24
#   Origin AS count: 1
# Prefix: 121.184.187.0/24
#   Origin AS count: 1
# Prefix: 175.213.217.0/24
#   Origin AS count: 1
# Prefix: 121.184.186.0/24
#   Origin AS count: 1
# Prefix: 121.184.189.0/24
#   Origin AS count: 1
# Prefix: 121.184.188.0/24
#   Origin AS count: 1
# Prefix: 203.243.39.0/24
#   Origin AS count: 1
# Prefix: 121.140.104.0/24
#   Origin AS count: 1
# Prefix: 165.141.176.0/21
#   Origin AS count: 1
# Prefix: 221.144.191.0/24
#   Origin AS count: 1
# Prefix: 116.193.82.0/24
#   Origin AS count: 1
# Prefix: 59.5.12.0/24
#   Origin AS count: 1
# Prefix: 147.43.28.0/22
#   Origin AS count: 1
# Prefix: 210.181.37.0/24
#   Origin AS count: 1
# Prefix: 14.206.18.0/24
#   Origin AS count: 1
# Prefix: 211.104.86.0/24
#   Origin AS count: 1
# Prefix: 61.106.176.0/24
#   Origin AS count: 1
# Prefix: 210.110.79.0/24
#   Origin AS count: 1
# Prefix: 222.119.39.0/24
#   Origin AS count: 1
# Prefix: 211.174.78.0/24
#   Origin AS count: 1
# Prefix: 203.249.10.0/24
#   Origin AS count: 1
# Prefix: 1.227.168.0/24
#   Origin AS count: 1
# Prefix: 1.231.184.0/24
#   Origin AS count: 1
# Prefix: 220.67.248.0/24
#   Origin AS count: 1
# Prefix: 220.67.249.0/24
#   Origin AS count: 1
# Prefix: 220.67.250.0/24
#   Origin AS count: 1
# Prefix: 1.231.183.0/24
#   Origin AS count: 1
# Prefix: 220.67.251.0/24
#   Origin AS count: 1
# Prefix: 1.231.182.0/24
#   Origin AS count: 1
# Prefix: 220.66.248.0/24
#   Origin AS count: 1
# Prefix: 220.67.252.0/24
#   Origin AS count: 1
# Prefix: 220.67.253.0/24
#   Origin AS count: 1
# Prefix: 220.66.250.0/24
#   Origin AS count: 1
# Prefix: 220.67.254.0/24
#   Origin AS count: 1
# Prefix: 220.69.248.0/23
#   Origin AS count: 1
# Prefix: 114.71.94.0/24
#   Origin AS count: 1
# Prefix: 114.71.95.0/24
#   Origin AS count: 1
# Prefix: 101.250.168.0/24
#   Origin AS count: 1
# Prefix: 101.250.171.0/24
#   Origin AS count: 1
# Prefix: 101.250.170.0/24
#   Origin AS count: 1
# Prefix: 101.250.165.0/24
#   Origin AS count: 1
# Prefix: 101.250.164.0/24
#   Origin AS count: 1
# Prefix: 101.250.167.0/24
#   Origin AS count: 1
# Prefix: 101.250.166.0/24
#   Origin AS count: 1
# Prefix: 101.250.161.0/24
#   Origin AS count: 1
# Prefix: 101.250.160.0/24
#   Origin AS count: 1
# Prefix: 101.250.163.0/24
#   Origin AS count: 1
# Prefix: 101.250.162.0/24
#   Origin AS count: 1
# Prefix: 101.250.189.0/24
#   Origin AS count: 1
# Prefix: 101.250.188.0/24
#   Origin AS count: 1
# Prefix: 210.93.128.0/24
#   Origin AS count: 1
# Prefix: 61.106.179.0/24
#   Origin AS count: 1
# Prefix: 210.110.76.0/24
#   Origin AS count: 1
# Prefix: 218.159.128.0/21
#   Origin AS count: 1
# Prefix: 211.174.77.0/24
#   Origin AS count: 1
# Prefix: 203.249.9.0/24
#   Origin AS count: 1
# Prefix: 210.93.129.0/24
#   Origin AS count: 1
# Prefix: 61.106.178.0/24
#   Origin AS count: 1
# Prefix: 210.110.77.0/24
#   Origin AS count: 1
# Prefix: 121.159.34.0/23
#   Origin AS count: 1
# Prefix: 203.249.8.0/24
#   Origin AS count: 1
# Prefix: 203.251.0.0/17
#   Origin AS count: 1
# Prefix: 220.73.208.0/22
#   Origin AS count: 1
# Prefix: 220.149.160.0/24
#   Origin AS count: 1
# Prefix: 203.249.7.0/24
#   Origin AS count: 1
# Prefix: 203.252.19.0/24
#   Origin AS count: 1
# Prefix: 61.106.188.0/24
#   Origin AS count: 1
# Prefix: 220.149.161.0/24
#   Origin AS count: 1
# Prefix: 221.157.128.0/23
#   Origin AS count: 1
# Prefix: 203.249.6.0/24
#   Origin AS count: 1
# Prefix: 203.252.18.0/24
#   Origin AS count: 1
# Prefix: 147.6.161.0/24
#   Origin AS count: 1
# Prefix: 61.106.191.0/24
#   Origin AS count: 1
# Prefix: 210.126.0.0/17
#   Origin AS count: 1
# Prefix: 220.149.162.0/24
#   Origin AS count: 1
# Prefix: 218.159.140.0/23
#   Origin AS count: 1
# Prefix: 203.249.5.0/24
#   Origin AS count: 1
# Prefix: 203.252.17.0/24
#   Origin AS count: 1
# Prefix: 147.6.160.0/24
#   Origin AS count: 1
# Prefix: 211.62.0.0/18
#   Origin AS count: 1
# Prefix: 210.123.21.0/24
#   Origin AS count: 1
# Prefix: 220.149.163.0/24
#   Origin AS count: 1
# Prefix: 211.174.64.0/19
#   Origin AS count: 1
# Prefix: 211.220.136.0/23
#   Origin AS count: 1
# Prefix: 203.249.4.0/24
#   Origin AS count: 1
# Prefix: 203.252.16.0/24
#   Origin AS count: 1
# Prefix: 211.52.47.0/24
#   Origin AS count: 1
# Prefix: 220.90.152.0/22
#   Origin AS count: 1
# Prefix: 61.106.185.0/24
#   Origin AS count: 1
# Prefix: 210.125.10.0/24
#   Origin AS count: 1
# Prefix: 203.252.23.0/24
#   Origin AS count: 1
# Prefix: 61.106.184.0/24
#   Origin AS count: 1
# Prefix: 118.36.200.0/23
#   Origin AS count: 1
# Prefix: 211.52.45.0/24
#   Origin AS count: 1
# Prefix: 61.82.91.0/24
#   Origin AS count: 1
# Prefix: 210.101.104.0/23
#   Origin AS count: 1
# Prefix: 61.106.187.0/24
#   Origin AS count: 1
# Prefix: 218.159.136.0/22
#   Origin AS count: 1
# Prefix: 203.252.21.0/24
#   Origin AS count: 1
# Prefix: 59.11.56.0/23
#   Origin AS count: 1
# Prefix: 211.39.96.0/19
#   Origin AS count: 1
# Prefix: 220.93.135.0/24
#   Origin AS count: 1
# Prefix: 61.106.186.0/24
#   Origin AS count: 1
# Prefix: 203.252.20.0/24
#   Origin AS count: 1
# Prefix: 211.46.91.0/24
#   Origin AS count: 1
# Prefix: 218.149.190.0/24
#   Origin AS count: 1
# Prefix: 117.17.0.0/22
#   Origin AS count: 1
# Prefix: 211.46.90.0/24
#   Origin AS count: 1
# Prefix: 218.149.191.0/24
#   Origin AS count: 1
# Prefix: 175.202.182.0/24
#   Origin AS count: 1
# Prefix: 211.222.141.0/24
#   Origin AS count: 1
# Prefix: 147.43.24.0/22
#   Origin AS count: 1
# Prefix: 147.43.20.0/22
#   Origin AS count: 1
# Prefix: 147.43.19.0/24
#   Origin AS count: 1
# Prefix: 147.43.17.0/24
#   Origin AS count: 1
# Prefix: 210.126.13.0/24
#   Origin AS count: 1
# Prefix: 211.199.232.0/24
#   Origin AS count: 1
# Prefix: 14.206.17.0/24
#   Origin AS count: 1
# Prefix: 117.16.29.0/24
#   Origin AS count: 1
# Prefix: 117.16.28.0/24
#   Origin AS count: 1
# Prefix: 117.16.31.0/24
#   Origin AS count: 1
# Prefix: 117.16.30.0/24
#   Origin AS count: 1
# Prefix: 117.16.25.0/24
#   Origin AS count: 1
# Prefix: 117.16.27.0/24
#   Origin AS count: 1
# Prefix: 117.16.26.0/24
#   Origin AS count: 1
# Prefix: 117.16.5.0/24
#   Origin AS count: 1
# Prefix: 117.16.7.0/24
#   Origin AS count: 1
# Prefix: 14.49.226.0/24
#   Origin AS count: 1
# Prefix: 14.49.227.0/24
#   Origin AS count: 1
# Prefix: 14.49.224.0/24
#   Origin AS count: 1
# Prefix: 14.49.225.0/24
#   Origin AS count: 1
# Prefix: 14.49.230.0/24
#   Origin AS count: 1
# Prefix: 14.49.231.0/24
#   Origin AS count: 1
# Prefix: 14.49.228.0/24
#   Origin AS count: 1
# Prefix: 14.49.229.0/24
#   Origin AS count: 1
# Prefix: 222.110.78.0/24
#   Origin AS count: 1
# Prefix: 211.193.255.0/24
#   Origin AS count: 1
# Prefix: 114.70.67.0/24
#   Origin AS count: 1
# Prefix: 114.70.68.0/24
#   Origin AS count: 1
# Prefix: 114.70.69.0/24
#   Origin AS count: 1
# Prefix: 182.31.224.0/21
#   Origin AS count: 1
# Prefix: 182.31.248.0/21
#   Origin AS count: 1
# Prefix: 211.241.61.0/24
#   Origin AS count: 1
# Prefix: 211.241.60.0/24
#   Origin AS count: 1
# Prefix: 203.236.80.0/24
#   Origin AS count: 1

# %% [markdown]
# # BGP Analysis Capabilities
#
# 3. AS Path Length and Change Summary
#
# Summarize the AS paths for each prefix associated with ASN [target ASN] over the period [start time] to [end time]. Provide minimum, maximum, and median AS path lengths and highlight any significant path changes observed in BGP updates.

# %%
# Import necessary libraries
import pybgpstream
from datetime import datetime
from statistics import median
from collections import defaultdict

def analyze_as_paths():
    # Define the time range
    from_time = "2024-10-28 13:00:00"
    until_time = "2024-10-28 13:15:00"

    # Initialize BGPStream
    stream = pybgpstream.BGPStream(
        from_time=from_time,
        until_time=until_time,
        record_type="updates"
    )

    # Initialize data structures
    prefix_paths = defaultdict(list)  # Store AS paths for each prefix
    path_changes = defaultdict(list)  # Track significant path changes per prefix

    # Iterate over records and elements
    for rec in stream.records():
        for elem in rec:
            # Extract element information
            elem_time = datetime.utcfromtimestamp(elem.time)
            elem_type = elem.type  # 'A' for announcements, 'W' for withdrawals
            fields = elem.fields
            prefix = fields.get("prefix")

            if prefix is None:
                continue  # Skip elements without prefix information

            # Extract AS path and check if AS4766 is in the path
            as_path_str = fields.get('as-path', "")
            as_path = as_path_str.split()
            if '4766' not in as_path:
                continue  # Only process paths that contain AS4766

            # Only process announcement messages
            if elem_type == 'A':
                path_length = len(as_path)
                prefix_paths[prefix].append((as_path, path_length, elem_time))

    # Summarize AS path lengths and detect changes
    for prefix, paths in prefix_paths.items():
        path_lengths = [length for _, length, _ in paths]
        min_length = min(path_lengths)
        max_length = max(path_lengths)
        median_length = median(path_lengths)

        # Detect significant AS path changes
        previous_path = None
        for as_path, length, time in paths:
            if previous_path and as_path != previous_path:
                path_changes[prefix].append((time, previous_path, as_path))
            previous_path = as_path

        # Output the summary
        print(f"Prefix: {prefix}")
        print(f"  Minimum AS path length: {min_length}")
        print(f"  Maximum AS path length: {max_length}")
        print(f"  Median AS path length: {median_length}")

        if path_changes[prefix]:
            print("  Significant AS path changes observed:")
            for change_time, old_path, new_path in path_changes[prefix]:
                print(f"    - At {change_time}: {old_path} -> {new_path}")

if __name__ == "__main__":
    analyze_as_paths()

# %%
import os
import re
import pybgpstream
from datetime import datetime, timezone
from statistics import median
from collections import defaultdict

def analyze_local_as_paths():
    from_time_str = "2024-10-28 13:00:00"
    until_time_str = "2024-10-28 13:15:00"
    target_asn = "4766"

    from_time = datetime.strptime(from_time_str, "%Y-%m-%d %H:%M:%S").replace(tzinfo=timezone.utc)
    until_time = datetime.strptime(until_time_str, "%Y-%m-%d %H:%M:%S").replace(tzinfo=timezone.utc)

    directory = "/home/hb/ris_bgp_updates/2024/10/rrc00"
    pattern = r'^updates\.(\d{8})\.(\d{4})\.(bz2|gz)$'

    prefix_paths = defaultdict(list)
    path_changes = defaultdict(list)

    for root, _, files in os.walk(directory):
        for file in files:
            match = re.match(pattern, file)
            if match:
                date_str = match.group(1)
                time_str = match.group(2)
                file_timestamp_str = date_str + time_str
                file_time = datetime.strptime(file_timestamp_str, "%Y%m%d%H%M").replace(tzinfo=timezone.utc)
                if file_time < from_time or file_time > until_time:
                    continue

                file_path = os.path.join(root, file)
                print(f"Processing file: {file_path}")
                stream = pybgpstream.BGPStream(data_interface="singlefile")
                stream.set_data_interface_option("singlefile", "upd-file", file_path)

                for rec in stream.records():
                    for elem in rec:
                        elem_time = datetime.utcfromtimestamp(elem.time).replace(tzinfo=timezone.utc)
                        if elem_time < from_time or elem_time > until_time:
                            continue
                        fields = elem.fields
                        prefix = fields.get("prefix")
                        if not prefix:
                            continue
                        as_path_str = fields.get('as-path', "")
                        as_path = as_path_str.split()
                        if target_asn not in as_path:
                            continue
                        if elem.type == 'A':
                            path_len = len(as_path)
                            prefix_paths[prefix].append((as_path, path_len, elem_time))

    for prefix, paths in prefix_paths.items():
        lengths = [length for _, length, _ in paths]
        min_len = min(lengths)
        max_len = max(lengths)
        med_len = median(lengths)

        prev_path = None
        for as_path, length, time in paths:
            if prev_path and as_path != prev_path:
                path_changes[prefix].append((time, prev_path, as_path))
            prev_path = as_path

        print(f"Prefix: {prefix}")
        print(f"  Min AS path length: {min_len}")
        print(f"  Max AS path length: {max_len}")
        print(f"  Median AS path length: {med_len}")
        if path_changes[prefix]:
            print("  Significant AS path changes observed:")
            for t, old_path, new_path in path_changes[prefix]:
                print(f"    - At {t}: {old_path} -> {new_path}")

if __name__ == "__main__":
    analyze_local_as_paths()
# Out:
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1315.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1300.gz
# Prefix: 14.55.70.0/23
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6.0
# Prefix: 14.55.72.0/23
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6.0
# Prefix: 1.34.184.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 211.52.3.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 220.67.208.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.69.200.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.95.160.0/20
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 211.104.115.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 168.126.80.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 218.146.146.0/24
#   Min AS path length: 8
#   Max AS path length: 8
#   Median AS path length: 8
# Prefix: 14.206.54.0/24
#   Min AS path length: 10
#   Max AS path length: 10
#   Median AS path length: 10
# Prefix: 101.250.141.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 117.16.52.0/23
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 211.52.2.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 220.67.209.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.69.201.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 101.101.240.0/21
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 183.106.30.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 117.111.200.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 121.126.128.0/17
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 203.237.126.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 101.250.140.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 182.31.200.0/21
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 14.50.196.0/22
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.67.210.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.69.202.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 183.106.29.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 222.118.4.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 168.126.82.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 121.137.95.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 218.146.144.0/24
#   Min AS path length: 8
#   Max AS path length: 8
#   Median AS path length: 8
# Prefix: 202.160.72.0/21
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 203.237.125.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 101.250.143.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 211.52.0.0/18
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 220.67.211.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.69.203.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 115.92.0.0/24
#   Min AS path length: 8
#   Max AS path length: 8
#   Median AS path length: 8
# Prefix: 183.106.28.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 121.137.94.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 218.146.145.0/24
#   Min AS path length: 8
#   Max AS path length: 8
#   Median AS path length: 8
# Prefix: 221.162.86.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 203.230.80.0/20
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 203.236.120.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 203.237.124.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 101.250.142.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 211.251.60.0/22
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 211.52.7.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 220.67.212.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.69.204.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 121.137.89.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 203.237.123.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 101.250.137.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 211.52.6.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 220.67.213.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.69.205.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 121.136.92.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 121.137.88.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 211.170.126.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 121.186.148.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 203.237.122.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 101.250.136.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 14.50.192.0/21
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 14.50.192.0/22
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 211.52.5.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 211.55.9.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.67.214.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.69.206.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 210.97.80.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 210.101.64.0/18
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 121.150.39.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 218.151.128.0/17
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 203.237.121.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 101.250.139.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 211.52.4.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 220.67.215.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.69.207.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 61.106.146.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 39.126.216.0/21
#   Min AS path length: 12
#   Max AS path length: 12
#   Median AS path length: 12
# Prefix: 121.137.90.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 211.216.180.0/22
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 203.237.120.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 203.243.0.0/18
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 101.250.138.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 211.251.56.0/22
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 211.252.36.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 211.253.32.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 117.16.61.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 61.34.189.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 211.39.71.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 211.52.11.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 220.67.216.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.69.192.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 110.92.22.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 210.110.98.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 221.164.69.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 113.198.97.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 203.237.119.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 101.250.133.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 117.16.60.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 211.39.70.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 211.52.10.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 220.67.217.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.69.193.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 210.110.99.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 39.126.214.0/23
#   Min AS path length: 12
#   Max AS path length: 12
#   Median AS path length: 12
# Prefix: 220.126.45.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 121.157.4.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 221.164.68.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 113.198.96.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 203.237.118.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 101.250.132.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 117.16.63.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 115.22.33.0/24
#   Min AS path length: 14
#   Max AS path length: 14
#   Median AS path length: 14
# Prefix: 14.63.248.0/23
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 220.66.222.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.67.218.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.69.194.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 210.110.96.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 121.137.87.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 221.164.71.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 113.198.99.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 211.223.165.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 203.237.117.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 101.250.135.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 147.6.128.0/17
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 117.16.62.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 115.22.32.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.66.223.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.67.219.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.69.195.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 110.92.21.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 210.110.97.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 222.121.49.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 115.144.56.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 180.150.231.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 221.164.70.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 113.198.98.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 211.222.160.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 211.223.164.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 203.237.116.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 211.246.0.0/17
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 101.250.134.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 211.251.52.0/22
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.67.220.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.69.196.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.71.204.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 210.110.102.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 220.116.0.0/14
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 175.195.175.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 203.237.115.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 101.250.129.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 220.67.221.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.69.197.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 125.140.64.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 125.140.64.0/18
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 180.150.225.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 121.157.0.0/22
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 203.237.114.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 125.243.188.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 101.250.128.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 211.253.42.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 14.50.200.0/21
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.67.222.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.69.198.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 58.103.168.0/23
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 210.110.100.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 180.150.226.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 203.237.113.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 101.250.131.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 211.253.41.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 220.67.223.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.69.199.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 183.78.128.0/20
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 210.99.81.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 210.110.101.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 121.126.142.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 125.140.66.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 118.128.121.0/24
#   Min AS path length: 9
#   Max AS path length: 9
#   Median AS path length: 9
# Prefix: 180.150.227.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 211.175.96.0/23
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 203.237.112.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 101.250.130.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 211.251.48.0/22
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 218.48.10.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 211.52.19.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 220.67.192.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.69.216.0/21
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.73.232.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.95.176.0/20
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 115.144.35.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.149.152.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 121.191.149.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 203.237.111.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 101.250.157.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 211.52.18.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 220.67.193.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.73.233.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 61.97.168.0/21
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 101.101.224.0/22
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 165.141.128.0/19
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.149.153.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 203.237.110.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 101.250.156.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 182.31.216.0/21
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 211.52.17.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 220.67.194.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.73.234.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 220.90.166.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 220.149.154.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 218.152.168.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 121.191.151.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 203.237.109.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 101.250.159.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 59.18.96.0/19
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 211.48.0.0/16
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 211.56.32.0/19
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 220.67.195.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.73.235.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 27.96.136.0/21
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 39.126.204.0/23
#   Min AS path length: 12
#   Max AS path length: 12
#   Median AS path length: 12
# Prefix: 121.133.126.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.149.155.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 121.150.50.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 182.172.21.0/24
#   Min AS path length: 12
#   Max AS path length: 12
#   Median AS path length: 12
# Prefix: 121.191.150.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 203.234.112.0/22
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 203.235.116.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 203.237.108.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 203.246.0.0/17
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 101.250.158.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 211.251.44.0/22
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 117.16.33.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 211.52.23.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 220.66.192.0/22
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.67.196.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.73.236.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 61.84.121.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 168.115.112.0/20
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 115.144.39.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 203.237.107.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 101.250.153.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 117.16.32.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 211.52.22.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 220.67.197.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 210.99.75.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 61.106.128.0/18
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 1.231.136.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 203.237.106.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 101.250.152.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 211.52.21.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 220.67.198.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 211.106.109.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 203.237.105.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 101.250.155.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 117.16.34.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 211.35.72.0/21
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 211.52.20.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 220.67.199.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 103.68.96.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 211.113.0.0/17
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 39.126.200.0/22
#   Min AS path length: 12
#   Max AS path length: 12
#   Median AS path length: 12
# Prefix: 49.142.30.0/23
#   Min AS path length: 12
#   Max AS path length: 12
#   Median AS path length: 12
# Prefix: 220.149.159.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 210.183.25.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 211.193.192.0/21
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 203.237.104.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 101.250.154.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 211.251.40.0/22
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 211.253.48.0/21
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 211.52.27.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 220.67.200.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.69.208.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 203.237.103.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 101.250.149.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 211.52.26.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 14.63.235.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 220.67.201.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.69.209.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 61.97.160.0/21
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 61.106.140.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 221.150.156.0/23
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 121.152.0.0/13
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 175.192.182.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 211.198.210.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 43.228.162.0/23
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 101.250.148.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 182.31.208.0/21
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 211.52.25.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 220.67.202.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.69.210.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 210.105.108.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 221.159.187.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 210.178.0.0/16
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 175.192.181.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 203.237.101.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 101.250.151.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 59.8.0.0/13
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 59.8.0.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 59.25.68.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 211.52.24.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 220.67.203.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.69.211.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 39.126.196.0/22
#   Min AS path length: 12
#   Max AS path length: 12
#   Median AS path length: 12
# Prefix: 221.159.186.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 43.228.160.0/23
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 203.237.100.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 101.250.150.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 59.25.67.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.67.204.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.69.212.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 39.126.195.0/24
#   Min AS path length: 12
#   Max AS path length: 12
#   Median AS path length: 12
# Prefix: 218.154.174.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 101.250.145.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 211.253.59.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 59.25.66.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.67.205.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.69.213.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 61.72.0.0/13
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 210.96.79.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 218.154.175.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 121.191.152.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 210.204.255.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 211.225.74.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 14.63.236.0/22
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 222.112.0.0/13
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 210.179.0.0/16
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 203.225.81.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 168.248.86.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 211.51.0.0/16
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 183.78.144.0/20
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 222.121.37.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 218.154.173.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 211.253.56.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 61.106.181.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 210.110.74.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 125.137.121.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 203.249.15.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 203.253.31.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 117.17.16.0/20
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 61.106.180.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 210.110.75.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 121.159.36.0/22
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 203.234.66.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 203.249.14.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 211.46.73.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 211.52.33.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 210.97.116.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 210.104.80.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 61.106.183.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 210.110.72.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 119.194.93.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 203.249.13.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 211.253.5.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 115.20.0.0/17
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 61.106.182.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 210.110.73.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 125.137.122.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 221.159.130.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 211.188.0.0/20
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 121.191.166.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 203.249.12.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 211.252.0.0/15
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 59.18.87.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 220.90.144.0/21
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 61.106.177.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 210.110.78.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 124.198.64.0/18
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 203.249.11.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 39.126.194.0/24
#   Min AS path length: 12
#   Max AS path length: 12
#   Median AS path length: 12
# Prefix: 39.126.192.0/23
#   Min AS path length: 12
#   Max AS path length: 12
#   Median AS path length: 12
# Prefix: 49.143.45.0/24
#   Min AS path length: 12
#   Max AS path length: 12
#   Median AS path length: 12
# Prefix: 49.143.44.0/24
#   Min AS path length: 12
#   Max AS path length: 12
#   Median AS path length: 12
# Prefix: 49.143.47.0/24
#   Min AS path length: 12
#   Max AS path length: 12
#   Median AS path length: 12
# Prefix: 49.143.46.0/24
#   Min AS path length: 12
#   Max AS path length: 12
#   Median AS path length: 12
# Prefix: 121.170.204.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 203.237.98.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.67.206.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 203.237.97.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.67.207.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 203.237.96.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 117.16.16.0/20
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 117.16.16.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 101.250.144.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 101.250.147.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 175.207.140.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 101.250.146.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 101.250.173.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 101.250.172.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 101.250.175.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 101.250.174.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 101.250.169.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 59.25.65.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 59.25.64.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.73.230.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.73.231.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 115.88.13.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 183.109.29.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 103.122.145.0/24
#   Min AS path length: 8
#   Max AS path length: 8
#   Median AS path length: 8
# Prefix: 203.235.121.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 218.48.5.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.66.244.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.66.247.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 1.231.185.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 211.193.200.0/21
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 61.83.85.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 14.49.234.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 14.49.235.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 14.49.232.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 14.49.233.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 61.73.57.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 218.145.190.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 218.154.146.0/23
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 218.154.144.0/23
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 121.184.185.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 121.184.184.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 121.184.187.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 175.213.217.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 121.184.186.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 121.184.189.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 121.184.188.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 203.243.39.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 121.140.104.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 165.141.176.0/21
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 221.144.191.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 116.193.82.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 59.5.12.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 147.43.28.0/22
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 210.181.37.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 14.206.18.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 211.104.86.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 61.106.176.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 210.110.79.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 222.119.39.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 211.174.78.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 203.249.10.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 1.227.168.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 1.231.184.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.67.248.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.67.249.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.67.250.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 1.231.183.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.67.251.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 1.231.182.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.66.248.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.67.252.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.67.253.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.66.250.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.67.254.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 220.69.248.0/23
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 114.71.94.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 114.71.95.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 101.250.168.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 101.250.171.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 101.250.170.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 101.250.165.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 101.250.164.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 101.250.167.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 101.250.166.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 101.250.161.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 101.250.160.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 101.250.163.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 101.250.162.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 101.250.189.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 101.250.188.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 210.93.128.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 61.106.179.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 210.110.76.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 218.159.128.0/21
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 211.174.77.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 203.249.9.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 210.93.129.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 61.106.178.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 210.110.77.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 121.159.34.0/23
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 203.249.8.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 203.251.0.0/17
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 220.73.208.0/22
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 220.149.160.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 203.249.7.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 203.252.19.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 61.106.188.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 220.149.161.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 221.157.128.0/23
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 203.249.6.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 203.252.18.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 147.6.161.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 61.106.191.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 210.126.0.0/17
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 220.149.162.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 218.159.140.0/23
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 203.249.5.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 203.252.17.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 147.6.160.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 211.62.0.0/18
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 210.123.21.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 220.149.163.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 211.174.64.0/19
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 211.220.136.0/23
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 203.249.4.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 203.252.16.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 211.52.47.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 220.90.152.0/22
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 61.106.185.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 210.125.10.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 203.252.23.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 61.106.184.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 118.36.200.0/23
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 211.52.45.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 61.82.91.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 210.101.104.0/23
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 61.106.187.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 218.159.136.0/22
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 203.252.21.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 59.11.56.0/23
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 211.39.96.0/19
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 220.93.135.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 61.106.186.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 203.252.20.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 211.46.91.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 218.149.190.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 117.17.0.0/22
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 211.46.90.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 218.149.191.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 175.202.182.0/24
#   Min AS path length: 5
#   Max AS path length: 5
#   Median AS path length: 5
# Prefix: 211.222.141.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 147.43.24.0/22
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 147.43.20.0/22
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 147.43.19.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 147.43.17.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 210.126.13.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 211.199.232.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 14.206.17.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 117.16.29.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 117.16.28.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 117.16.31.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 117.16.30.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 117.16.25.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 117.16.27.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 117.16.26.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 117.16.5.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 117.16.7.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 14.49.226.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 14.49.227.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 14.49.224.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 14.49.225.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 14.49.230.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 14.49.231.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 14.49.228.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 14.49.229.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 222.110.78.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 211.193.255.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 114.70.67.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 114.70.68.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 114.70.69.0/24
#   Min AS path length: 7
#   Max AS path length: 7
#   Median AS path length: 7
# Prefix: 182.31.224.0/21
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 182.31.248.0/21
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 211.241.61.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 211.241.60.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6
# Prefix: 203.236.80.0/24
#   Min AS path length: 6
#   Max AS path length: 6
#   Median AS path length: 6

# %% [markdown]
# # BGP Analysis Capabilities
#
# 4. Prefix Stability Analysis
#
# Identify prefixes associated with ASN [target ASN] that show high update frequency (announcements and withdrawals) within the period [start time] to [end time]. Summarize the prefixes, update counts, and provide an assessment of their stability.

# %%
# Import necessary libraries
import pybgpstream
from datetime import datetime
from collections import defaultdict

def analyze_high_update_frequency():
    # Define the time range
    from_time = "2024-10-28 13:00:00"
    until_time = "2024-10-28 13:15:00"

    # Initialize BGPStream
    stream = pybgpstream.BGPStream(
        from_time=from_time,
        until_time=until_time,
        record_type="updates"
    )

    # Data structures to track update counts
    update_counts = defaultdict(int)

    # Iterate over records and elements
    for rec in stream.records():
        for elem in rec:
            # Extract element information
            elem_time = datetime.utcfromtimestamp(elem.time)
            elem_type = elem.type  # 'A' for announcements, 'W' for withdrawals
            fields = elem.fields
            prefix = fields.get("prefix")
            if prefix is None:
                continue  # Skip elements without prefix information

            # Extract AS path and check if AS4766 is in the AS path
            as_path_str = fields.get('as-path', "")
            as_path = as_path_str.split()
            if '4766' not in as_path:
                continue  # Only process paths containing AS4766

            # Count announcements and withdrawals for each prefix
            update_counts[prefix] += 1

    # Assess prefix stability based on update frequency
    print("Prefixes associated with AS4766 and their update frequency:")
    for prefix, count in update_counts.items():
        stability = "Unstable" if count > 10 else "Stable"  # Define threshold for stability
        print(f"Prefix: {prefix}, Update Count: {count}, Stability: {stability}")

if __name__ == "__main__":
    analyze_high_update_frequency()

# %%
import os
import re
import pybgpstream
from datetime import datetime, timezone
from collections import defaultdict

def analyze_local_high_update_frequency():
    # Define the time window and target ASN
    from_time_str = "2024-10-28 13:00:00"
    until_time_str = "2024-10-28 13:15:00"
    target_asn = "4766"

    # Parse into timezone-aware datetime objects
    from_time = datetime.strptime(from_time_str, "%Y-%m-%d %H:%M:%S").replace(tzinfo=timezone.utc)
    until_time = datetime.strptime(until_time_str, "%Y-%m-%d %H:%M:%S").replace(tzinfo=timezone.utc)

    # Directory containing BGP update files
    directory = "/home/hb/ris_bgp_updates/2024/10/rrc00"

    # Regex pattern for matching filenames: updates.YYYYMMDD.HHMM.gz (or .bz2)
    pattern = r'^updates\.(\d{8})\.(\d{4})\.(bz2|gz)$'

    # Data structure to track update counts per prefix
    update_counts = defaultdict(int)

    # Traverse the directory and filter files by time window
    for root, _, files in os.walk(directory):
        for file in files:
            match = re.match(pattern, file)
            if match:
                date_str = match.group(1)  # YYYYMMDD
                time_str = match.group(2)  # HHMM
                file_timestamp_str = date_str + time_str
                file_time = datetime.strptime(file_timestamp_str, "%Y%m%d%H%M").replace(tzinfo=timezone.utc)
                if file_time < from_time or file_time > until_time:
                    continue

                file_path = os.path.join(root, file)
                print(f"Processing file: {file_path}")
                stream = pybgpstream.BGPStream(data_interface="singlefile")
                stream.set_data_interface_option("singlefile", "upd-file", file_path)

                # Iterate over records in this file
                for rec in stream.records():
                    for elem in rec:
                        elem_time = datetime.utcfromtimestamp(elem.time).replace(tzinfo=timezone.utc)
                        if elem_time < from_time or elem_time > until_time:
                            continue

                        elem_type = elem.type  # 'A' (announcement), 'W' (withdrawal)
                        fields = elem.fields
                        prefix = fields.get("prefix")
                        if not prefix:
                            continue

                        as_path_str = fields.get('as-path', "")
                        as_path = as_path_str.split()
                        if target_asn not in as_path:
                            continue

                        # Count updates for each prefix referencing target_asn
                        if elem_type in {'A', 'W'}:
                            update_counts[prefix] += 1

    # Assess prefix stability based on update frequency
    print("\nPrefixes referencing AS4766 and their update frequency:")
    for prefix, count in update_counts.items():
        stability = "Unstable" if count > 10 else "Stable"
        print(f"  Prefix: {prefix}, Update Count: {count}, Stability: {stability}")

if __name__ == "__main__":
    analyze_local_high_update_frequency()
# Out:
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1315.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1300.gz
#
# Prefixes referencing AS4766 and their update frequency:
#   Prefix: 14.55.70.0/23, Update Count: 2, Stability: Stable
#   Prefix: 14.55.72.0/23, Update Count: 2, Stability: Stable
#   Prefix: 1.34.184.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.52.3.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.67.208.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.69.200.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.95.160.0/20, Update Count: 1, Stability: Stable
#   Prefix: 211.104.115.0/24, Update Count: 1, Stability: Stable
#   Prefix: 168.126.80.0/24, Update Count: 1, Stability: Stable
#   Prefix: 218.146.146.0/24, Update Count: 1, Stability: Stable
#   Prefix: 14.206.54.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.141.0/24, Update Count: 1, Stability: Stable
#   Prefix: 117.16.52.0/23, Update Count: 1, Stability: Stable
#   Prefix: 211.52.2.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.67.209.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.69.201.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.101.240.0/21, Update Count: 1, Stability: Stable
#   Prefix: 183.106.30.0/24, Update Count: 1, Stability: Stable
#   Prefix: 117.111.200.0/24, Update Count: 1, Stability: Stable
#   Prefix: 121.126.128.0/17, Update Count: 1, Stability: Stable
#   Prefix: 203.237.126.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.140.0/24, Update Count: 1, Stability: Stable
#   Prefix: 182.31.200.0/21, Update Count: 1, Stability: Stable
#   Prefix: 14.50.196.0/22, Update Count: 1, Stability: Stable
#   Prefix: 220.67.210.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.69.202.0/24, Update Count: 1, Stability: Stable
#   Prefix: 183.106.29.0/24, Update Count: 1, Stability: Stable
#   Prefix: 222.118.4.0/24, Update Count: 1, Stability: Stable
#   Prefix: 168.126.82.0/24, Update Count: 1, Stability: Stable
#   Prefix: 121.137.95.0/24, Update Count: 1, Stability: Stable
#   Prefix: 218.146.144.0/24, Update Count: 1, Stability: Stable
#   Prefix: 202.160.72.0/21, Update Count: 1, Stability: Stable
#   Prefix: 203.237.125.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.143.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.52.0.0/18, Update Count: 1, Stability: Stable
#   Prefix: 220.67.211.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.69.203.0/24, Update Count: 1, Stability: Stable
#   Prefix: 115.92.0.0/24, Update Count: 1, Stability: Stable
#   Prefix: 183.106.28.0/24, Update Count: 1, Stability: Stable
#   Prefix: 121.137.94.0/24, Update Count: 1, Stability: Stable
#   Prefix: 218.146.145.0/24, Update Count: 1, Stability: Stable
#   Prefix: 221.162.86.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.230.80.0/20, Update Count: 1, Stability: Stable
#   Prefix: 203.236.120.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.237.124.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.142.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.251.60.0/22, Update Count: 1, Stability: Stable
#   Prefix: 211.52.7.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.67.212.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.69.204.0/24, Update Count: 1, Stability: Stable
#   Prefix: 121.137.89.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.237.123.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.137.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.52.6.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.67.213.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.69.205.0/24, Update Count: 1, Stability: Stable
#   Prefix: 121.136.92.0/24, Update Count: 1, Stability: Stable
#   Prefix: 121.137.88.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.170.126.0/24, Update Count: 1, Stability: Stable
#   Prefix: 121.186.148.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.237.122.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.136.0/24, Update Count: 1, Stability: Stable
#   Prefix: 14.50.192.0/21, Update Count: 1, Stability: Stable
#   Prefix: 14.50.192.0/22, Update Count: 1, Stability: Stable
#   Prefix: 211.52.5.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.55.9.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.67.214.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.69.206.0/24, Update Count: 1, Stability: Stable
#   Prefix: 210.97.80.0/24, Update Count: 1, Stability: Stable
#   Prefix: 210.101.64.0/18, Update Count: 1, Stability: Stable
#   Prefix: 121.150.39.0/24, Update Count: 1, Stability: Stable
#   Prefix: 218.151.128.0/17, Update Count: 1, Stability: Stable
#   Prefix: 203.237.121.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.139.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.52.4.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.67.215.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.69.207.0/24, Update Count: 1, Stability: Stable
#   Prefix: 61.106.146.0/24, Update Count: 1, Stability: Stable
#   Prefix: 39.126.216.0/21, Update Count: 1, Stability: Stable
#   Prefix: 121.137.90.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.216.180.0/22, Update Count: 1, Stability: Stable
#   Prefix: 203.237.120.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.243.0.0/18, Update Count: 1, Stability: Stable
#   Prefix: 101.250.138.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.251.56.0/22, Update Count: 1, Stability: Stable
#   Prefix: 211.252.36.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.253.32.0/24, Update Count: 1, Stability: Stable
#   Prefix: 117.16.61.0/24, Update Count: 1, Stability: Stable
#   Prefix: 61.34.189.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.39.71.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.52.11.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.67.216.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.69.192.0/24, Update Count: 1, Stability: Stable
#   Prefix: 110.92.22.0/24, Update Count: 1, Stability: Stable
#   Prefix: 210.110.98.0/24, Update Count: 1, Stability: Stable
#   Prefix: 221.164.69.0/24, Update Count: 1, Stability: Stable
#   Prefix: 113.198.97.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.237.119.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.133.0/24, Update Count: 1, Stability: Stable
#   Prefix: 117.16.60.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.39.70.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.52.10.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.67.217.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.69.193.0/24, Update Count: 1, Stability: Stable
#   Prefix: 210.110.99.0/24, Update Count: 1, Stability: Stable
#   Prefix: 39.126.214.0/23, Update Count: 1, Stability: Stable
#   Prefix: 220.126.45.0/24, Update Count: 1, Stability: Stable
#   Prefix: 121.157.4.0/24, Update Count: 1, Stability: Stable
#   Prefix: 221.164.68.0/24, Update Count: 1, Stability: Stable
#   Prefix: 113.198.96.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.237.118.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.132.0/24, Update Count: 1, Stability: Stable
#   Prefix: 117.16.63.0/24, Update Count: 1, Stability: Stable
#   Prefix: 115.22.33.0/24, Update Count: 1, Stability: Stable
#   Prefix: 14.63.248.0/23, Update Count: 1, Stability: Stable
#   Prefix: 220.66.222.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.67.218.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.69.194.0/24, Update Count: 1, Stability: Stable
#   Prefix: 210.110.96.0/24, Update Count: 1, Stability: Stable
#   Prefix: 121.137.87.0/24, Update Count: 1, Stability: Stable
#   Prefix: 221.164.71.0/24, Update Count: 1, Stability: Stable
#   Prefix: 113.198.99.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.223.165.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.237.117.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.135.0/24, Update Count: 1, Stability: Stable
#   Prefix: 147.6.128.0/17, Update Count: 1, Stability: Stable
#   Prefix: 117.16.62.0/24, Update Count: 1, Stability: Stable
#   Prefix: 115.22.32.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.66.223.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.67.219.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.69.195.0/24, Update Count: 1, Stability: Stable
#   Prefix: 110.92.21.0/24, Update Count: 1, Stability: Stable
#   Prefix: 210.110.97.0/24, Update Count: 1, Stability: Stable
#   Prefix: 222.121.49.0/24, Update Count: 1, Stability: Stable
#   Prefix: 115.144.56.0/24, Update Count: 1, Stability: Stable
#   Prefix: 180.150.231.0/24, Update Count: 1, Stability: Stable
#   Prefix: 221.164.70.0/24, Update Count: 1, Stability: Stable
#   Prefix: 113.198.98.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.222.160.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.223.164.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.237.116.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.246.0.0/17, Update Count: 1, Stability: Stable
#   Prefix: 101.250.134.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.251.52.0/22, Update Count: 1, Stability: Stable
#   Prefix: 220.67.220.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.69.196.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.71.204.0/24, Update Count: 1, Stability: Stable
#   Prefix: 210.110.102.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.116.0.0/14, Update Count: 1, Stability: Stable
#   Prefix: 175.195.175.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.237.115.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.129.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.67.221.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.69.197.0/24, Update Count: 1, Stability: Stable
#   Prefix: 125.140.64.0/24, Update Count: 1, Stability: Stable
#   Prefix: 125.140.64.0/18, Update Count: 1, Stability: Stable
#   Prefix: 180.150.225.0/24, Update Count: 1, Stability: Stable
#   Prefix: 121.157.0.0/22, Update Count: 1, Stability: Stable
#   Prefix: 203.237.114.0/24, Update Count: 1, Stability: Stable
#   Prefix: 125.243.188.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.128.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.253.42.0/24, Update Count: 1, Stability: Stable
#   Prefix: 14.50.200.0/21, Update Count: 1, Stability: Stable
#   Prefix: 220.67.222.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.69.198.0/24, Update Count: 1, Stability: Stable
#   Prefix: 58.103.168.0/23, Update Count: 1, Stability: Stable
#   Prefix: 210.110.100.0/24, Update Count: 1, Stability: Stable
#   Prefix: 180.150.226.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.237.113.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.131.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.253.41.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.67.223.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.69.199.0/24, Update Count: 1, Stability: Stable
#   Prefix: 183.78.128.0/20, Update Count: 1, Stability: Stable
#   Prefix: 210.99.81.0/24, Update Count: 1, Stability: Stable
#   Prefix: 210.110.101.0/24, Update Count: 1, Stability: Stable
#   Prefix: 121.126.142.0/24, Update Count: 1, Stability: Stable
#   Prefix: 125.140.66.0/24, Update Count: 1, Stability: Stable
#   Prefix: 118.128.121.0/24, Update Count: 1, Stability: Stable
#   Prefix: 180.150.227.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.175.96.0/23, Update Count: 1, Stability: Stable
#   Prefix: 203.237.112.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.130.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.251.48.0/22, Update Count: 1, Stability: Stable
#   Prefix: 218.48.10.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.52.19.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.67.192.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.69.216.0/21, Update Count: 1, Stability: Stable
#   Prefix: 220.73.232.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.95.176.0/20, Update Count: 1, Stability: Stable
#   Prefix: 115.144.35.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.149.152.0/24, Update Count: 1, Stability: Stable
#   Prefix: 121.191.149.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.237.111.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.157.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.52.18.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.67.193.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.73.233.0/24, Update Count: 1, Stability: Stable
#   Prefix: 61.97.168.0/21, Update Count: 1, Stability: Stable
#   Prefix: 101.101.224.0/22, Update Count: 1, Stability: Stable
#   Prefix: 165.141.128.0/19, Update Count: 1, Stability: Stable
#   Prefix: 220.149.153.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.237.110.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.156.0/24, Update Count: 1, Stability: Stable
#   Prefix: 182.31.216.0/21, Update Count: 1, Stability: Stable
#   Prefix: 211.52.17.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.67.194.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.73.234.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.90.166.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.149.154.0/24, Update Count: 1, Stability: Stable
#   Prefix: 218.152.168.0/24, Update Count: 1, Stability: Stable
#   Prefix: 121.191.151.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.237.109.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.159.0/24, Update Count: 1, Stability: Stable
#   Prefix: 59.18.96.0/19, Update Count: 1, Stability: Stable
#   Prefix: 211.48.0.0/16, Update Count: 1, Stability: Stable
#   Prefix: 211.56.32.0/19, Update Count: 1, Stability: Stable
#   Prefix: 220.67.195.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.73.235.0/24, Update Count: 1, Stability: Stable
#   Prefix: 27.96.136.0/21, Update Count: 1, Stability: Stable
#   Prefix: 39.126.204.0/23, Update Count: 1, Stability: Stable
#   Prefix: 121.133.126.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.149.155.0/24, Update Count: 1, Stability: Stable
#   Prefix: 121.150.50.0/24, Update Count: 1, Stability: Stable
#   Prefix: 182.172.21.0/24, Update Count: 1, Stability: Stable
#   Prefix: 121.191.150.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.234.112.0/22, Update Count: 1, Stability: Stable
#   Prefix: 203.235.116.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.237.108.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.246.0.0/17, Update Count: 1, Stability: Stable
#   Prefix: 101.250.158.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.251.44.0/22, Update Count: 1, Stability: Stable
#   Prefix: 117.16.33.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.52.23.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.66.192.0/22, Update Count: 1, Stability: Stable
#   Prefix: 220.67.196.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.73.236.0/24, Update Count: 1, Stability: Stable
#   Prefix: 61.84.121.0/24, Update Count: 1, Stability: Stable
#   Prefix: 168.115.112.0/20, Update Count: 1, Stability: Stable
#   Prefix: 115.144.39.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.237.107.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.153.0/24, Update Count: 1, Stability: Stable
#   Prefix: 117.16.32.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.52.22.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.67.197.0/24, Update Count: 1, Stability: Stable
#   Prefix: 210.99.75.0/24, Update Count: 1, Stability: Stable
#   Prefix: 61.106.128.0/18, Update Count: 1, Stability: Stable
#   Prefix: 1.231.136.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.237.106.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.152.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.52.21.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.67.198.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.106.109.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.237.105.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.155.0/24, Update Count: 1, Stability: Stable
#   Prefix: 117.16.34.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.35.72.0/21, Update Count: 1, Stability: Stable
#   Prefix: 211.52.20.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.67.199.0/24, Update Count: 1, Stability: Stable
#   Prefix: 103.68.96.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.113.0.0/17, Update Count: 1, Stability: Stable
#   Prefix: 39.126.200.0/22, Update Count: 1, Stability: Stable
#   Prefix: 49.142.30.0/23, Update Count: 1, Stability: Stable
#   Prefix: 220.149.159.0/24, Update Count: 1, Stability: Stable
#   Prefix: 210.183.25.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.193.192.0/21, Update Count: 1, Stability: Stable
#   Prefix: 203.237.104.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.154.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.251.40.0/22, Update Count: 1, Stability: Stable
#   Prefix: 211.253.48.0/21, Update Count: 1, Stability: Stable
#   Prefix: 211.52.27.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.67.200.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.69.208.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.237.103.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.149.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.52.26.0/24, Update Count: 1, Stability: Stable
#   Prefix: 14.63.235.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.67.201.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.69.209.0/24, Update Count: 1, Stability: Stable
#   Prefix: 61.97.160.0/21, Update Count: 1, Stability: Stable
#   Prefix: 61.106.140.0/24, Update Count: 1, Stability: Stable
#   Prefix: 221.150.156.0/23, Update Count: 1, Stability: Stable
#   Prefix: 121.152.0.0/13, Update Count: 1, Stability: Stable
#   Prefix: 175.192.182.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.198.210.0/24, Update Count: 1, Stability: Stable
#   Prefix: 43.228.162.0/23, Update Count: 1, Stability: Stable
#   Prefix: 101.250.148.0/24, Update Count: 1, Stability: Stable
#   Prefix: 182.31.208.0/21, Update Count: 1, Stability: Stable
#   Prefix: 211.52.25.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.67.202.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.69.210.0/24, Update Count: 1, Stability: Stable
#   Prefix: 210.105.108.0/24, Update Count: 1, Stability: Stable
#   Prefix: 221.159.187.0/24, Update Count: 1, Stability: Stable
#   Prefix: 210.178.0.0/16, Update Count: 1, Stability: Stable
#   Prefix: 175.192.181.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.237.101.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.151.0/24, Update Count: 1, Stability: Stable
#   Prefix: 59.8.0.0/13, Update Count: 1, Stability: Stable
#   Prefix: 59.8.0.0/24, Update Count: 1, Stability: Stable
#   Prefix: 59.25.68.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.52.24.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.67.203.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.69.211.0/24, Update Count: 1, Stability: Stable
#   Prefix: 39.126.196.0/22, Update Count: 1, Stability: Stable
#   Prefix: 221.159.186.0/24, Update Count: 1, Stability: Stable
#   Prefix: 43.228.160.0/23, Update Count: 1, Stability: Stable
#   Prefix: 203.237.100.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.150.0/24, Update Count: 1, Stability: Stable
#   Prefix: 59.25.67.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.67.204.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.69.212.0/24, Update Count: 1, Stability: Stable
#   Prefix: 39.126.195.0/24, Update Count: 1, Stability: Stable
#   Prefix: 218.154.174.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.145.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.253.59.0/24, Update Count: 1, Stability: Stable
#   Prefix: 59.25.66.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.67.205.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.69.213.0/24, Update Count: 1, Stability: Stable
#   Prefix: 61.72.0.0/13, Update Count: 1, Stability: Stable
#   Prefix: 210.96.79.0/24, Update Count: 1, Stability: Stable
#   Prefix: 218.154.175.0/24, Update Count: 1, Stability: Stable
#   Prefix: 121.191.152.0/24, Update Count: 1, Stability: Stable
#   Prefix: 210.204.255.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.225.74.0/24, Update Count: 1, Stability: Stable
#   Prefix: 14.63.236.0/22, Update Count: 1, Stability: Stable
#   Prefix: 222.112.0.0/13, Update Count: 1, Stability: Stable
#   Prefix: 210.179.0.0/16, Update Count: 1, Stability: Stable
#   Prefix: 203.225.81.0/24, Update Count: 1, Stability: Stable
#   Prefix: 168.248.86.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.51.0.0/16, Update Count: 1, Stability: Stable
#   Prefix: 183.78.144.0/20, Update Count: 1, Stability: Stable
#   Prefix: 222.121.37.0/24, Update Count: 1, Stability: Stable
#   Prefix: 218.154.173.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.253.56.0/24, Update Count: 1, Stability: Stable
#   Prefix: 61.106.181.0/24, Update Count: 1, Stability: Stable
#   Prefix: 210.110.74.0/24, Update Count: 1, Stability: Stable
#   Prefix: 125.137.121.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.249.15.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.253.31.0/24, Update Count: 1, Stability: Stable
#   Prefix: 117.17.16.0/20, Update Count: 1, Stability: Stable
#   Prefix: 61.106.180.0/24, Update Count: 1, Stability: Stable
#   Prefix: 210.110.75.0/24, Update Count: 1, Stability: Stable
#   Prefix: 121.159.36.0/22, Update Count: 1, Stability: Stable
#   Prefix: 203.234.66.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.249.14.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.46.73.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.52.33.0/24, Update Count: 1, Stability: Stable
#   Prefix: 210.97.116.0/24, Update Count: 1, Stability: Stable
#   Prefix: 210.104.80.0/24, Update Count: 1, Stability: Stable
#   Prefix: 61.106.183.0/24, Update Count: 1, Stability: Stable
#   Prefix: 210.110.72.0/24, Update Count: 1, Stability: Stable
#   Prefix: 119.194.93.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.249.13.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.253.5.0/24, Update Count: 1, Stability: Stable
#   Prefix: 115.20.0.0/17, Update Count: 1, Stability: Stable
#   Prefix: 61.106.182.0/24, Update Count: 1, Stability: Stable
#   Prefix: 210.110.73.0/24, Update Count: 1, Stability: Stable
#   Prefix: 125.137.122.0/24, Update Count: 1, Stability: Stable
#   Prefix: 221.159.130.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.188.0.0/20, Update Count: 1, Stability: Stable
#   Prefix: 121.191.166.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.249.12.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.252.0.0/15, Update Count: 1, Stability: Stable
#   Prefix: 59.18.87.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.90.144.0/21, Update Count: 1, Stability: Stable
#   Prefix: 61.106.177.0/24, Update Count: 1, Stability: Stable
#   Prefix: 210.110.78.0/24, Update Count: 1, Stability: Stable
#   Prefix: 124.198.64.0/18, Update Count: 1, Stability: Stable
#   Prefix: 203.249.11.0/24, Update Count: 1, Stability: Stable
#   Prefix: 39.126.194.0/24, Update Count: 1, Stability: Stable
#   Prefix: 39.126.192.0/23, Update Count: 1, Stability: Stable
#   Prefix: 49.143.45.0/24, Update Count: 1, Stability: Stable
#   Prefix: 49.143.44.0/24, Update Count: 1, Stability: Stable
#   Prefix: 49.143.47.0/24, Update Count: 1, Stability: Stable
#   Prefix: 49.143.46.0/24, Update Count: 1, Stability: Stable
#   Prefix: 121.170.204.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.237.98.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.67.206.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.237.97.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.67.207.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.237.96.0/24, Update Count: 1, Stability: Stable
#   Prefix: 117.16.16.0/20, Update Count: 1, Stability: Stable
#   Prefix: 117.16.16.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.144.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.147.0/24, Update Count: 1, Stability: Stable
#   Prefix: 175.207.140.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.146.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.173.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.172.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.175.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.174.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.169.0/24, Update Count: 1, Stability: Stable
#   Prefix: 59.25.65.0/24, Update Count: 1, Stability: Stable
#   Prefix: 59.25.64.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.73.230.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.73.231.0/24, Update Count: 1, Stability: Stable
#   Prefix: 115.88.13.0/24, Update Count: 1, Stability: Stable
#   Prefix: 183.109.29.0/24, Update Count: 1, Stability: Stable
#   Prefix: 103.122.145.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.235.121.0/24, Update Count: 1, Stability: Stable
#   Prefix: 218.48.5.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.66.244.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.66.247.0/24, Update Count: 1, Stability: Stable
#   Prefix: 1.231.185.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.193.200.0/21, Update Count: 1, Stability: Stable
#   Prefix: 61.83.85.0/24, Update Count: 1, Stability: Stable
#   Prefix: 14.49.234.0/24, Update Count: 1, Stability: Stable
#   Prefix: 14.49.235.0/24, Update Count: 1, Stability: Stable
#   Prefix: 14.49.232.0/24, Update Count: 1, Stability: Stable
#   Prefix: 14.49.233.0/24, Update Count: 1, Stability: Stable
#   Prefix: 61.73.57.0/24, Update Count: 1, Stability: Stable
#   Prefix: 218.145.190.0/24, Update Count: 1, Stability: Stable
#   Prefix: 218.154.146.0/23, Update Count: 1, Stability: Stable
#   Prefix: 218.154.144.0/23, Update Count: 1, Stability: Stable
#   Prefix: 121.184.185.0/24, Update Count: 1, Stability: Stable
#   Prefix: 121.184.184.0/24, Update Count: 1, Stability: Stable
#   Prefix: 121.184.187.0/24, Update Count: 1, Stability: Stable
#   Prefix: 175.213.217.0/24, Update Count: 1, Stability: Stable
#   Prefix: 121.184.186.0/24, Update Count: 1, Stability: Stable
#   Prefix: 121.184.189.0/24, Update Count: 1, Stability: Stable
#   Prefix: 121.184.188.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.243.39.0/24, Update Count: 1, Stability: Stable
#   Prefix: 121.140.104.0/24, Update Count: 1, Stability: Stable
#   Prefix: 165.141.176.0/21, Update Count: 1, Stability: Stable
#   Prefix: 221.144.191.0/24, Update Count: 1, Stability: Stable
#   Prefix: 116.193.82.0/24, Update Count: 1, Stability: Stable
#   Prefix: 59.5.12.0/24, Update Count: 1, Stability: Stable
#   Prefix: 147.43.28.0/22, Update Count: 1, Stability: Stable
#   Prefix: 210.181.37.0/24, Update Count: 1, Stability: Stable
#   Prefix: 14.206.18.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.104.86.0/24, Update Count: 1, Stability: Stable
#   Prefix: 61.106.176.0/24, Update Count: 1, Stability: Stable
#   Prefix: 210.110.79.0/24, Update Count: 1, Stability: Stable
#   Prefix: 222.119.39.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.174.78.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.249.10.0/24, Update Count: 1, Stability: Stable
#   Prefix: 1.227.168.0/24, Update Count: 1, Stability: Stable
#   Prefix: 1.231.184.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.67.248.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.67.249.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.67.250.0/24, Update Count: 1, Stability: Stable
#   Prefix: 1.231.183.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.67.251.0/24, Update Count: 1, Stability: Stable
#   Prefix: 1.231.182.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.66.248.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.67.252.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.67.253.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.66.250.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.67.254.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.69.248.0/23, Update Count: 1, Stability: Stable
#   Prefix: 114.71.94.0/24, Update Count: 1, Stability: Stable
#   Prefix: 114.71.95.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.168.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.171.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.170.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.165.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.164.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.167.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.166.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.161.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.160.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.163.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.162.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.189.0/24, Update Count: 1, Stability: Stable
#   Prefix: 101.250.188.0/24, Update Count: 1, Stability: Stable
#   Prefix: 210.93.128.0/24, Update Count: 1, Stability: Stable
#   Prefix: 61.106.179.0/24, Update Count: 1, Stability: Stable
#   Prefix: 210.110.76.0/24, Update Count: 1, Stability: Stable
#   Prefix: 218.159.128.0/21, Update Count: 1, Stability: Stable
#   Prefix: 211.174.77.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.249.9.0/24, Update Count: 1, Stability: Stable
#   Prefix: 210.93.129.0/24, Update Count: 1, Stability: Stable
#   Prefix: 61.106.178.0/24, Update Count: 1, Stability: Stable
#   Prefix: 210.110.77.0/24, Update Count: 1, Stability: Stable
#   Prefix: 121.159.34.0/23, Update Count: 1, Stability: Stable
#   Prefix: 203.249.8.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.251.0.0/17, Update Count: 1, Stability: Stable
#   Prefix: 220.73.208.0/22, Update Count: 1, Stability: Stable
#   Prefix: 220.149.160.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.249.7.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.252.19.0/24, Update Count: 1, Stability: Stable
#   Prefix: 61.106.188.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.149.161.0/24, Update Count: 1, Stability: Stable
#   Prefix: 221.157.128.0/23, Update Count: 1, Stability: Stable
#   Prefix: 203.249.6.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.252.18.0/24, Update Count: 1, Stability: Stable
#   Prefix: 147.6.161.0/24, Update Count: 1, Stability: Stable
#   Prefix: 61.106.191.0/24, Update Count: 1, Stability: Stable
#   Prefix: 210.126.0.0/17, Update Count: 1, Stability: Stable
#   Prefix: 220.149.162.0/24, Update Count: 1, Stability: Stable
#   Prefix: 218.159.140.0/23, Update Count: 1, Stability: Stable
#   Prefix: 203.249.5.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.252.17.0/24, Update Count: 1, Stability: Stable
#   Prefix: 147.6.160.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.62.0.0/18, Update Count: 1, Stability: Stable
#   Prefix: 210.123.21.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.149.163.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.174.64.0/19, Update Count: 1, Stability: Stable
#   Prefix: 211.220.136.0/23, Update Count: 1, Stability: Stable
#   Prefix: 203.249.4.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.252.16.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.52.47.0/24, Update Count: 1, Stability: Stable
#   Prefix: 220.90.152.0/22, Update Count: 1, Stability: Stable
#   Prefix: 61.106.185.0/24, Update Count: 1, Stability: Stable
#   Prefix: 210.125.10.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.252.23.0/24, Update Count: 1, Stability: Stable
#   Prefix: 61.106.184.0/24, Update Count: 1, Stability: Stable
#   Prefix: 118.36.200.0/23, Update Count: 1, Stability: Stable
#   Prefix: 211.52.45.0/24, Update Count: 1, Stability: Stable
#   Prefix: 61.82.91.0/24, Update Count: 1, Stability: Stable
#   Prefix: 210.101.104.0/23, Update Count: 1, Stability: Stable
#   Prefix: 61.106.187.0/24, Update Count: 1, Stability: Stable
#   Prefix: 218.159.136.0/22, Update Count: 1, Stability: Stable
#   Prefix: 203.252.21.0/24, Update Count: 1, Stability: Stable
#   Prefix: 59.11.56.0/23, Update Count: 1, Stability: Stable
#   Prefix: 211.39.96.0/19, Update Count: 1, Stability: Stable
#   Prefix: 220.93.135.0/24, Update Count: 1, Stability: Stable
#   Prefix: 61.106.186.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.252.20.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.46.91.0/24, Update Count: 1, Stability: Stable
#   Prefix: 218.149.190.0/24, Update Count: 1, Stability: Stable
#   Prefix: 117.17.0.0/22, Update Count: 1, Stability: Stable
#   Prefix: 211.46.90.0/24, Update Count: 1, Stability: Stable
#   Prefix: 218.149.191.0/24, Update Count: 1, Stability: Stable
#   Prefix: 175.202.182.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.222.141.0/24, Update Count: 1, Stability: Stable
#   Prefix: 147.43.24.0/22, Update Count: 1, Stability: Stable
#   Prefix: 147.43.20.0/22, Update Count: 1, Stability: Stable
#   Prefix: 147.43.19.0/24, Update Count: 1, Stability: Stable
#   Prefix: 147.43.17.0/24, Update Count: 1, Stability: Stable
#   Prefix: 210.126.13.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.199.232.0/24, Update Count: 1, Stability: Stable
#   Prefix: 14.206.17.0/24, Update Count: 1, Stability: Stable
#   Prefix: 117.16.29.0/24, Update Count: 1, Stability: Stable
#   Prefix: 117.16.28.0/24, Update Count: 1, Stability: Stable
#   Prefix: 117.16.31.0/24, Update Count: 1, Stability: Stable
#   Prefix: 117.16.30.0/24, Update Count: 1, Stability: Stable
#   Prefix: 117.16.25.0/24, Update Count: 1, Stability: Stable
#   Prefix: 117.16.27.0/24, Update Count: 1, Stability: Stable
#   Prefix: 117.16.26.0/24, Update Count: 1, Stability: Stable
#   Prefix: 117.16.5.0/24, Update Count: 1, Stability: Stable
#   Prefix: 117.16.7.0/24, Update Count: 1, Stability: Stable
#   Prefix: 14.49.226.0/24, Update Count: 1, Stability: Stable
#   Prefix: 14.49.227.0/24, Update Count: 1, Stability: Stable
#   Prefix: 14.49.224.0/24, Update Count: 1, Stability: Stable
#   Prefix: 14.49.225.0/24, Update Count: 1, Stability: Stable
#   Prefix: 14.49.230.0/24, Update Count: 1, Stability: Stable
#   Prefix: 14.49.231.0/24, Update Count: 1, Stability: Stable
#   Prefix: 14.49.228.0/24, Update Count: 1, Stability: Stable
#   Prefix: 14.49.229.0/24, Update Count: 1, Stability: Stable
#   Prefix: 222.110.78.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.193.255.0/24, Update Count: 1, Stability: Stable
#   Prefix: 114.70.67.0/24, Update Count: 1, Stability: Stable
#   Prefix: 114.70.68.0/24, Update Count: 1, Stability: Stable
#   Prefix: 114.70.69.0/24, Update Count: 1, Stability: Stable
#   Prefix: 182.31.224.0/21, Update Count: 1, Stability: Stable
#   Prefix: 182.31.248.0/21, Update Count: 1, Stability: Stable
#   Prefix: 211.241.61.0/24, Update Count: 1, Stability: Stable
#   Prefix: 211.241.60.0/24, Update Count: 1, Stability: Stable
#   Prefix: 203.236.80.0/24, Update Count: 1, Stability: Stable

# %% [markdown]
# # BGP Analysis Capabilities
#
# 5. Community and MED Analysis
#
# Analyze the range of MED values and the most common community tags associated with BGP update messages for ASN [target ASN] from [start time] to [end time]. Provide a summary of average MED values and frequently observed community tags.

# %%
import pybgpstream
from datetime import datetime
from collections import defaultdict, Counter
import statistics

def main():
    from_time = "2024-10-28 13:00:00"
    until_time = "2024-10-28 14:00:00"
    collectors = ["rrc00"]

    # Initialize BGPStream
    stream = pybgpstream.BGPStream(
        from_time=from_time,
        until_time=until_time,
        record_type="updates",
        collectors=collectors
    )

    target_asn = '4766'

    med_values = []
    community_tags = []

    # Iterate over records and elements
    for rec in stream.records():
        for elem in rec:
            fields = elem.fields
            elem_type = elem.type  # 'A' for announcements, 'W' for withdrawals

            as_path_str = fields.get('as-path', "")
            as_path = as_path_str.split()

            # Filter for AS4766 in the AS path
            if target_asn not in as_path:
                continue

            # Extract MED value
            med_value = fields.get('med')
            if med_value is not None:
                med_values.append(int(med_value))

            # Extract community tags
            communities = fields.get('communities', [])
            for community in communities:
                community_tags.append(community)

    # Calculate MED statistics
    if med_values:
        min_med = min(med_values)
        max_med = max(med_values)
        average_med = statistics.mean(med_values)
        print(f"MED Value Range: {min_med} - {max_med}")
        print(f"Average MED Value: {average_med}")
    else:
        print("No MED values found.")

    # Calculate most common community tags
    if community_tags:
        community_counter = Counter(community_tags)
        most_common_communities = community_counter.most_common(10)  # Top 10
        print("Most Common Community Tags:")
        for community, count in most_common_communities:
            print(f"  {community} (observed {count} times)")
    else:
        print("No community tags found.")

if __name__ == "__main__":
    main()
# Out:
# No MED values found.
# Most Common Community Tags:
#   34549:100 (observed 3074 times)
#   174:22013 (observed 2998 times)
#   34549:174 (observed 2994 times)
#   174:21001 (observed 2671 times)
#   174:21000 (observed 327 times)
#   1299:35000 (observed 77 times)
#   34549:1299 (observed 70 times)
#   24482:2 (observed 61 times)
#   24482:200 (observed 61 times)
#   48858:1399 (observed 47 times)

# %%
import os
import re
import pybgpstream
import statistics
from datetime import datetime, timezone
from collections import defaultdict, Counter

def analyze_local_med_community():
    from_time_str = "2024-10-28 13:00:00"
    until_time_str = "2024-10-28 14:00:00"
    target_asn = "4766"

    from_time = datetime.strptime(from_time_str, "%Y-%m-%d %H:%M:%S").replace(tzinfo=timezone.utc)
    until_time = datetime.strptime(until_time_str, "%Y-%m-%d %H:%M:%S").replace(tzinfo=timezone.utc)

    directory = "/home/hb/ris_bgp_updates/2024/10/rrc00"
    pattern = r'^updates\.(\d{8})\.(\d{4})\.(bz2|gz)$'

    med_values = []
    community_tags = []

    for root, _, files in os.walk(directory):
        for file in files:
            match = re.match(pattern, file)
            if match:
                date_str = match.group(1)
                time_str = match.group(2)
                file_timestamp_str = date_str + time_str
                file_time = datetime.strptime(file_timestamp_str, "%Y%m%d%H%M").replace(tzinfo=timezone.utc)

                if file_time < from_time or file_time > until_time:
                    continue

                file_path = os.path.join(root, file)
                print(f"Processing file: {file_path}")
                stream = pybgpstream.BGPStream(data_interface="singlefile")
                stream.set_data_interface_option("singlefile", "upd-file", file_path)

                for rec in stream.records():
                    for elem in rec:
                        elem_time = datetime.utcfromtimestamp(elem.time).replace(tzinfo=timezone.utc)
                        if elem_time < from_time or elem_time > until_time:
                            continue

                        fields = elem.fields
                        as_path_str = fields.get('as-path', "")
                        as_path = as_path_str.split()
                        if target_asn not in as_path:
                            continue

                        med_value = fields.get('med')
                        if med_value is not None:
                            try:
                                med_values.append(int(med_value))
                            except ValueError:
                                pass

                        communities = fields.get('communities', [])
                        for c in communities:
                            community_tags.append(c)

    if med_values:
        min_med = min(med_values)
        max_med = max(med_values)
        avg_med = statistics.mean(med_values)
        print(f"MED Value Range: {min_med} - {max_med}")
        print(f"Average MED Value: {avg_med}")
    else:
        print("No MED values found.")

    if community_tags:
        community_counter = Counter(community_tags)
        most_common_communities = community_counter.most_common(10)
        print("Most Common Community Tags:")
        for community, count in most_common_communities:
            print(f"  {community} (observed {count} times)")
    else:
        print("No community tags found.")

if __name__ == "__main__":
    analyze_local_med_community()
# Out:
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1400.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1330.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1345.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1315.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1300.gz
# No MED values found.
# Most Common Community Tags:
#   34549:100 (observed 557 times)
#   34549:174 (observed 549 times)
#   174:22013 (observed 549 times)
#   174:21001 (observed 503 times)
#   174:21000 (observed 46 times)
#   24482:11050 (observed 12 times)
#   9002:64819 (observed 12 times)
#   24482:11052 (observed 12 times)
#   24482:2 (observed 12 times)
#   24482:65116 (observed 12 times)

# %% [markdown]
# # BGP Analysis Capabilities
#
# 6. Update Count and Periodic Changes
#
# Summarize the count of BGP update messages (announcements and withdrawals) for ASN [target ASN] between [start time] and [end time]. Provide total counts as well as breakdowns by 5, 30, and 60-minute intervals.

# %% [markdown]
# # BGP Analysis Capabilities
#
# 7. Route Flapping Analysis
#
# Identify prefixes associated with ASN [target ASN] that exhibit flapping behavior within the period [start time] to [end time]. Summarize the prefixes, the number of flaps, and the duration between consecutive flaps.

# %%
import pybgpstream
import pandas as pd
from datetime import datetime

# Define parameters
asn = "4766"
start_time = "2024-10-28 13:00:00"
end_time = "2024-10-28 13:15:00"

# Configure BGPStream
stream = pybgpstream.BGPStream(
    from_time=start_time,
    until_time=end_time,
    record_type="updates",
    filter=f"origin {asn}"
)

# Initialize a list to store events
events = []

# Collect data
for rec in stream.records():
    for elem in rec:
        if elem.type in ['A', 'W']:
            prefix = elem.fields.get('prefix')
            timestamp = datetime.utcfromtimestamp(elem.time)
            event_type = elem.type  # 'A' for announcement, 'W' for withdrawal
            events.append({'prefix': prefix, 'timestamp': timestamp, 'event_type': event_type})

# Create DataFrame
df = pd.DataFrame(events)

# Identify flapping prefixes
flapping_info = []

for prefix, group in df.groupby('prefix'):
    group = group.sort_values('timestamp')
    # Detect changes in event_type (from A to W or W to A)
    group['change'] = group['event_type'].shift() != group['event_type']
    flap_events = group[group['change']]
    num_flaps = len(flap_events)
    if num_flaps > 1:
        # Calculate durations between consecutive flaps
        durations = flap_events['timestamp'].diff().dt.total_seconds().dropna()
        avg_duration = durations.mean()
        flapping_info.append({
            'prefix': prefix,
            'number_of_flaps': num_flaps,
            'average_duration_between_flaps_seconds': avg_duration
        })

# Create a DataFrame for flapping prefixes
flap_df = pd.DataFrame(flapping_info)

# Display the results
if not flap_df.empty:
    print("Flapping prefixes associated with ASN 4766:")
    print(flap_df)
else:
    print("No flapping prefixes detected for ASN 4766 in the given time period.")
# Out:
# No flapping prefixes detected for ASN 4766 in the given time period.

# %%
import os
import re
import pybgpstream
import pandas as pd
from datetime import datetime, timezone
from collections import defaultdict
import statistics

def analyze_local_flapping():
    from_time_str = "2024-10-28 13:00:00"
    until_time_str = "2024-10-29 13:00:00"
    target_asn = "4766"

    from_time = datetime.strptime(from_time_str, "%Y-%m-%d %H:%M:%S").replace(tzinfo=timezone.utc)
    until_time = datetime.strptime(until_time_str, "%Y-%m-%d %H:%M:%S").replace(tzinfo=timezone.utc)

    directory = "/home/hb/ris_bgp_updates/2024/10/rrc00"
    pattern = r'^updates\.(\d{8})\.(\d{4})\.(bz2|gz)$'

    events = []

    for root, _, files in os.walk(directory):
        for file in files:
            match = re.match(pattern, file)
            if match:
                date_str = match.group(1)
                time_str = match.group(2)
                file_timestamp_str = date_str + time_str
                file_time = datetime.strptime(file_timestamp_str, "%Y%m%d%H%M").replace(tzinfo=timezone.utc)

                if file_time < from_time or file_time > until_time:
                    continue

                file_path = os.path.join(root, file)
                print(f"Processing file: {file_path}")
                stream = pybgpstream.BGPStream(data_interface="singlefile")
                stream.set_data_interface_option("singlefile", "upd-file", file_path)

                for rec in stream.records():
                    for elem in rec:
                        elem_time = datetime.utcfromtimestamp(elem.time).replace(tzinfo=timezone.utc)
                        if elem_time < from_time or elem_time > until_time:
                            continue

                        fields = elem.fields
                        prefix = fields.get("prefix")
                        if not prefix:
                            continue

                        elem_type = elem.type
                        as_path_str = fields.get('as-path', "")
                        as_path = as_path_str.split()

                        # Filter for origin = target_asn (last in as_path)
                        if as_path and as_path[-1] == target_asn:
                            if elem_type in ('A', 'W'):
                                events.append({
                                    'prefix': prefix,
                                    'timestamp': elem_time,
                                    'event_type': elem_type
                                })

    df = pd.DataFrame(events)
    if df.empty:
        print(f"No updates found for origin {target_asn} in the given time period.")
        return

    flapping_info = []

    for prefix, group in df.groupby('prefix'):
        group = group.sort_values('timestamp')
        group['change'] = group['event_type'].shift() != group['event_type']
        flap_events = group[group['change']]
        num_flaps = len(flap_events)

        if num_flaps > 1:
            durations = flap_events['timestamp'].diff().dt.total_seconds().dropna()
            avg_duration = durations.mean() if not durations.empty else 0
            flapping_info.append({
                'prefix': prefix,
                'number_of_flaps': num_flaps,
                'average_duration_between_flaps_seconds': avg_duration
            })

    if not flapping_info:
        print(f"No flapping prefixes detected for ASN {target_asn} in the given time period.")
        return

    flap_df = pd.DataFrame(flapping_info)
    print(f"Flapping prefixes for origin {target_asn}:")
    print(flap_df)

if __name__ == "__main__":
    analyze_local_flapping()
# Out:
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.1300.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1945.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.1145.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1730.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1900.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0800.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.2300.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0545.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0445.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0230.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0700.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1400.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1330.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1815.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.2115.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.2200.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1545.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0500.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1515.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1430.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1845.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0645.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0115.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.1215.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1415.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0530.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0300.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1345.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.2345.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0030.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0245.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.1245.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0715.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.2145.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0945.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0730.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1600.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1700.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0400.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1800.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0215.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0315.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.1130.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0200.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0015.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1630.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.1200.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.1030.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0415.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0600.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.2000.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0900.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.2045.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0330.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1315.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.2330.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1830.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0915.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.1015.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1615.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0045.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.1115.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.2030.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0615.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.1230.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.2315.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0930.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.2015.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0145.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0130.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1745.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0100.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1530.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.2100.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1300.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1930.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.1100.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0815.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0430.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0845.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.2130.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0830.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0345.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.2245.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.1000.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1645.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1500.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0630.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.2230.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.1045.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1915.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0000.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1715.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1445.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.2215.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0745.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241029.0515.gz
# No flapping prefixes detected for ASN 4766 in the given time period.

# %% [markdown]
# # BGP Analysis Capabilities
#
# 8. Anomaly Detection - Prefix Announcement
#
# Identify any prefixes announced by ASN [target ASN] that exhibit anomalous announcement patterns during [start time] to [end time]. Summarize the prefixes, number of announcements, and rate of change compared to historical data.

# %%
import pybgpstream
import pandas as pd
from datetime import datetime, timedelta

# Define parameters
asn = "4766"
current_start_time = "2024-10-28 13:00:00"
current_end_time = "2024-10-28 13:15:00"

# Define historical period (e.g., one week before)
historical_start_time = (datetime.strptime(current_start_time, "%Y-%m-%d %H:%M:%S") - timedelta(weeks=54)).strftime("%Y-%m-%d %H:%M:%S")
historical_end_time = (datetime.strptime(current_end_time, "%Y-%m-%d %H:%M:%S") - timedelta(weeks=54)).strftime("%Y-%m-%d %H:%M:%S")

def collect_announcements(asn, start_time, end_time):
    stream = pybgpstream.BGPStream(
        from_time=start_time,
        until_time=end_time,
        record_type="updates",
        filter=f"origin {asn}"
    )
    prefixes = []
    for rec in stream.records():
        for elem in rec:
            if elem.type == 'A':
                prefix = elem.fields.get('prefix')
                prefixes.append(prefix)
    return pd.Series(prefixes).value_counts()

# Collect current and historical announcements
current_announcements = collect_announcements(asn, current_start_time, current_end_time)
historical_announcements = collect_announcements(asn, historical_start_time, historical_end_time)

# Combine and compare
df = pd.DataFrame({
    'current_count': current_announcements,
    'historical_count': historical_announcements
}).fillna(0)

df['rate_of_change'] = ((df['current_count'] - df['historical_count']) / df['historical_count'].replace(0, 1)) * 100

# Identify anomalous prefixes (e.g., rate of change > 50%)
anomalous_prefixes = df[df['rate_of_change'].abs() > 50]

# Display the results
if not anomalous_prefixes.empty:
    print("Anomalous prefixes announced by ASN 4766:")
    print(anomalous_prefixes)
else:
    print("No anomalous prefix announcements detected for ASN 4766 in the given time period.")
# Out:
# Anomalous prefixes announced by ASN 4766:
#                  current_count  historical_count  rate_of_change
# 1.100.0.0/14               2.0                 1           100.0
# 1.104.0.0/14               2.0                 1           100.0
# 1.108.0.0/14               2.0                 1           100.0
# 1.231.122.0/24             3.0                 1           200.0
# 1.231.13.0/24              2.0                 1           100.0
# ...                        ...               ...             ...
# 61.97.160.0/21             3.0                 1           200.0
# 61.97.168.0/21             3.0                 1           200.0
# 74.124.196.0/24            2.0                 1           100.0
# 92.112.57.0/24             2.0                 1           100.0
# 92.112.61.0/24             2.0                 1           100.0
#
# [984 rows x 3 columns]

# %% [markdown]
# # BGP Analysis Capabilities
#
# 9. Anomaly Detection - AS Path Changes
#
# Detect unusual AS path changes for prefixes associated with ASN [target ASN] from [start time] to [end time]. Summarize the prefixes, number of path changes, and frequency of these changes.

# %%
import pybgpstream
import pandas as pd

# Define parameters
asn = "4766"
start_time = "2024-10-28 13:00:00"
end_time = "2024-10-28 13:15:00"

# Configure BGPStream
stream = pybgpstream.BGPStream(
    from_time=start_time,
    until_time=end_time,
    record_type="updates",
    filter=f"origin {asn}"
)

# Initialize a dictionary to store AS paths per prefix
prefix_as_paths = {}

# Collect data
for rec in stream.records():
    for elem in rec:
        if elem.type == 'A':
            prefix = elem.fields.get('prefix')
            as_path = elem.fields.get('as-path', '')
            if prefix not in prefix_as_paths:
                prefix_as_paths[prefix] = set()
            prefix_as_paths[prefix].add(as_path)

# Analyze AS path changes
as_path_changes = []

for prefix, paths in prefix_as_paths.items():
    num_paths = len(paths)
    if num_paths > 1:
        as_path_changes.append({
            'prefix': prefix,
            'number_of_path_changes': num_paths,
            'as_paths': paths
        })

# Convert to DataFrame
df_as_changes = pd.DataFrame(as_path_changes)

# Display the results
if not df_as_changes.empty:
    print("Prefixes with AS path changes for ASN 4766:")
    print(df_as_changes)
else:
    print("No unusual AS path changes detected for ASN 4766 in the given time period.")
# Out:
# Prefixes with AS path changes for ASN 4766:
#               prefix  number_of_path_changes  \
# 0    2400:0:611::/48                       5
# 1    2400:0:810::/44                       7
# 2    2400:0:820::/44                       7
# 3    2400:0:830::/44                       7
# 4    2400:0:840::/44                       7
# ..               ...                     ...
# 672  211.38.114.0/24                       2
# 673   211.51.48.0/24                       2
# 674  211.33.209.0/24                       2
# 675   210.179.0.0/21                       2
# 676   210.113.7.0/24                       2
#
#                                               as_paths
# 0    {59890 3356 4766, 140731 137990 2914 4766, 134...
# 1    {207841 137409 174 4766, 59890 3356 4766, 1407...
# 2    {207841 137409 174 4766, 59890 3356 4766, 1407...
# 3    {207841 137409 174 4766, 59890 3356 4766, 1407...
# 4    {207841 137409 174 4766, 59890 3356 4766, 1407...
# ..                                                 ...
# 672  {27678 6429 27978 2914 174 4766, 27678 6429 27...
# 673  {27678 6429 27978 2914 174 4766, 27678 6429 27...
# 674  {27678 6429 27978 2914 174 4766, 27678 6429 27...
# 675  {27678 6429 27978 2914 174 4766, 27678 6429 27...
# 676  {27678 6429 27978 2914 174 4766, 27678 6429 27...
#
# [677 rows x 3 columns]

# %%
import os
import re
import pybgpstream
import pandas as pd
from datetime import datetime, timezone
from collections import defaultdict

def analyze_local_as_path_changes():
    # Define the time window and target ASN
    from_time_str = "2024-10-28 13:00:00"
    until_time_str = "2024-10-28 13:15:00"
    target_asn = "4766"

    # Parse time window
    from_time = datetime.strptime(from_time_str, "%Y-%m-%d %H:%M:%S").replace(tzinfo=timezone.utc)
    until_time = datetime.strptime(until_time_str, "%Y-%m-%d %H:%M:%S").replace(tzinfo=timezone.utc)

    # Directory containing BGP update files
    directory = "/home/hb/ris_bgp_updates/2024/10/rrc00"
    pattern = r'^updates\.(\d{8})\.(\d{4})\.(bz2|gz)$'

    prefix_as_paths = defaultdict(set)

    for root, _, files in os.walk(directory):
        for file in files:
            match = re.match(pattern, file)
            if match:
                date_str = match.group(1)
                time_str = match.group(2)
                file_timestamp_str = date_str + time_str
                file_time = datetime.strptime(file_timestamp_str, "%Y%m%d%H%M").replace(tzinfo=timezone.utc)

                if file_time < from_time or file_time > until_time:
                    continue

                file_path = os.path.join(root, file)
                stream = pybgpstream.BGPStream(data_interface="singlefile")
                stream.set_data_interface_option("singlefile", "upd-file", file_path)

                for rec in stream.records():
                    for elem in rec:
                        elem_time = datetime.utcfromtimestamp(elem.time).replace(tzinfo=timezone.utc)
                        if elem_time < from_time or elem_time > until_time:
                            continue
                        if elem.type == 'A':
                            fields = elem.fields
                            prefix = fields.get('prefix')
                            if not prefix:
                                continue

                            as_path_str = fields.get('as-path', '')
                            as_path = as_path_str.split()
                            prefix_as_paths[prefix].add(as_path_str)

    as_path_changes = []
    for prefix, path_set in prefix_as_paths.items():
        if len(path_set) > 1:
            as_path_changes.append({
                'prefix': prefix,
                'number_of_path_changes': len(path_set),
                'as_paths': list(path_set)
            })

    df_as_changes = pd.DataFrame(as_path_changes)
    if not df_as_changes.empty:
        print(f"Prefixes with AS path changes for ASN {target_asn}:")
        print(df_as_changes)
    else:
        print(f"No unusual AS path changes detected for ASN {target_asn} in the given time period.")

if __name__ == "__main__":
    analyze_local_as_path_changes()
# Out:
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1315.gz
# Processing file: /home/hb/ris_bgp_updates/2024/10/rrc00/updates.20241028.1300.gz
# Prefixes with AS path changes for ASN 4766:
#                   prefix  number_of_path_changes  \
# 0        223.196.46.0/24                     116
# 1        200.115.69.0/24                      12
# 2         2804:8330::/32                      55
# 3       169.145.140.0/23                      97
# 4      2a02:ac80:40::/48                     286
# ...                  ...                     ...
# 20905   162.247.202.0/24                       2
# 20906   162.247.200.0/24                       2
# 20907   162.247.206.0/24                       2
# 20908   192.245.167.0/24                       2
# 20909    204.117.91.0/24                       2
#
#                                                 as_paths
# 0      [3333 1103 3257 174 55644 55644 55644 55644 55...
# 1      [58057 34549 6461 52320 269194 270885 270885 2...
# 2      [34549 37468 262589 267027 272182, 56662 37468...
# 3      [1403 174 3356 14114 6979 6979 6979 6979 6979 ...
# 4      [17639 5511 6762 25145, 37721 6762 25145 34984...
# ...                                                  ...
# 20905  [24482 2914 3356 46347, 24482 64213 23118 2311...
# 20906  [24482 2914 3356 46347, 24482 64213 23118 2311...
# 20907  [24482 2914 3356 46347, 24482 64213 23118 2311...
# 20908  [24482 2914 3356 46347, 24482 64213 23118 2311...
# 20909  [24482 2914 3356 46347, 24482 64213 23118 2311...
#
# [20910 rows x 3 columns]

# %% [markdown]
# # BGP Analysis Capabilities
#
# 10. Anomaly Detection - Potential Hijacking
#
# Identify suspected BGP hijacking incidents involving ASN [target ASN] or its prefixes from [start time] to [end time]. Summarize the prefixes, unauthorized ASNs, and frequency of suspected hijacks.
#
#
# Define time window around the incident
# start_time = "2018-04-24 10:00:00"  # UTC
# end_time = "2018-04-24 12:00:00"    # UTC
#
# Target prefix and expected origin ASN
# target_prefix = "205.251.192.0/23"
# expected_asn = "16509"

# %% [markdown]
# Identify suspected BGP hijacking incidents involving AS16509 or its prefixes (177.93.174.0/23, 138.59.238.0/23, 177.93.168.0/23) from April 24 10:00 to 12:00, 2018. Summarize the prefixes, unauthorized ASNs, and frequency of suspected hijacks.

# %%
import pybgpstream
import pandas as pd
from datetime import datetime

# Define parameters
asn = "16509"
start_time = "2018-04-24 10:00:00"
end_time = "2018-04-24 12:00:00"

# Define known prefixes of ASN 16509
known_prefixes = set([
    "177.93.174.0/23",
    "138.59.238.0/23",
    "177.93.168.0/23",
    # Add more known prefixes for ASN 16509
])

# Initialize BGPStream
stream = pybgpstream.BGPStream(
    from_time=start_time,
    until_time=end_time,
    collectors=["rrc00"],
    record_type="updates",
)

# Initialize a dictionary to store unauthorized announcements
hijack_attempts = {}

# Collect data
for rec in stream.records():
    for elem in rec:
        if elem.type == 'A':
            prefix = elem.fields.get('prefix')
            as_path = elem.fields.get('as-path', '')
            as_path_list = as_path.strip().split()
            origin_asn = as_path_list[-1] if as_path_list else None

            # Check if the prefix is known and the origin ASN is not the target ASN
            if prefix in known_prefixes and origin_asn != asn:
                if prefix not in hijack_attempts:
                    hijack_attempts[prefix] = {'unauthorized_asns': set(), 'count': 0}
                hijack_attempts[prefix]['unauthorized_asns'].add(origin_asn)
                hijack_attempts[prefix]['count'] += 1

# Prepare the results
results = []
for prefix, data in hijack_attempts.items():
    results.append({
        'prefix': prefix,
        'unauthorized_asns': list(data['unauthorized_asns']),
        'frequency_of_suspected_hijacks': data['count']
    })

# Convert to DataFrame
df_hijacks = pd.DataFrame(results)

# Display the results
if not df_hijacks.empty:
    print(f"Suspected BGP hijacking incidents involving ASN {asn}:")
    print(df_hijacks)
else:
    print(f"No suspected hijacking incidents detected for ASN {asn} in the given time period.")
# Out:
# Suspected BGP hijacking incidents involving ASN 16509:
#             prefix unauthorized_asns  frequency_of_suspected_hijacks
# 0  177.93.168.0/23          [263154]                              11
# 1  177.93.174.0/23          [263154]                              11
# 2  138.59.238.0/23          [263154]                               9

# %%
import os
import re
import pybgpstream
import pandas as pd
from datetime import datetime, timezone
from collections import defaultdict

def analyze_local_hijacking():
    """
    Process locally stored BGP update files to detect suspected hijacking incidents 
    by comparing known prefixes of a target ASN against the observed origin ASNs.
    """

    # Define parameters
    asn = "16509"
    from_time_str = "2018-04-24 10:00:00"
    until_time_str = "2018-04-24 12:00:00"

    # Known prefixes for ASN 16509
    known_prefixes = {
        "177.93.174.0/23",
        "138.59.238.0/23",
        "177.93.168.0/23",
        # Add more known prefixes if needed
    }

    # Parse the time window strings into datetime objects (UTC)
    from_time = datetime.strptime(from_time_str, "%Y-%m-%d %H:%M:%S").replace(tzinfo=timezone.utc)
    until_time = datetime.strptime(until_time_str, "%Y-%m-%d %H:%M:%S").replace(tzinfo=timezone.utc)

    # Directory containing BGP update files
    directory = "/home/hb/ris_bgp_updates/2018/04/rrc00"

    # Regex pattern to match filenames: updates.YYYYMMDD.HHMM.gz or .bz2
    pattern = r'^updates\.(\d{8})\.(\d{4})\.(bz2|gz)$'

    # Dictionary to store unauthorized announcements
    hijack_attempts = defaultdict(lambda: {"unauthorized_asns": set(), "count": 0})

    for root, _, files in os.walk(directory):
        for file in files:
            match = re.match(pattern, file)
            if match:
                date_str = match.group(1)  # YYYYMMDD
                time_str = match.group(2)  # HHMM
                file_timestamp_str = date_str + time_str
                file_time = datetime.strptime(file_timestamp_str, "%Y%m%d%H%M").replace(tzinfo=timezone.utc)

                # Skip files outside the time window
                if file_time < from_time or file_time > until_time:
                    continue

                file_path = os.path.join(root, file)
                print(f"Processing file: {file_path}")

                # Initialize BGPStream for local file processing
                stream = pybgpstream.BGPStream(data_interface="singlefile")
                stream.set_data_interface_option("singlefile", "upd-file", file_path)

                # Collect data
                for rec in stream.records():
                    for elem in rec:
                        # Filter by element timestamp
                        elem_time = datetime.utcfromtimestamp(elem.time).replace(tzinfo=timezone.utc)
                        if elem_time < from_time or elem_time > until_time:
                            continue

                        if elem.type == "A":  # Only process announcements
                            fields = elem.fields
                            prefix = fields.get("prefix")
                            if not prefix:
                                continue

                            as_path_str = fields.get("as-path", "")
                            as_path_list = as_path_str.strip().split()
                            origin_asn = as_path_list[-1] if as_path_list else None

                            # Check if prefix is known and origin ASN differs from the target ASN
                            if prefix in known_prefixes and origin_asn != asn:
                                hijack_attempts[prefix]["unauthorized_asns"].add(origin_asn)
                                hijack_attempts[prefix]["count"] += 1

    # Prepare results
    results = []
    for prefix, data in hijack_attempts.items():
        results.append({
            "prefix": prefix,
            "unauthorized_asns": list(data["unauthorized_asns"]),
            "frequency_of_suspected_hijacks": data["count"]
        })

    df_hijacks = pd.DataFrame(results)
    if not df_hijacks.empty:
        print(f"Suspected BGP hijacking incidents involving ASN {asn}:")
        print(df_hijacks)
    else:
        print(f"No suspected hijacking incidents detected for ASN {asn} in the given time period.")

if __name__ == "__main__":
    analyze_local_hijacking()
# Out:
# Processing file: /home/hb/ris_bgp_updates/2018/04/rrc00/updates.20180424.1045.gz
# Processing file: /home/hb/ris_bgp_updates/2018/04/rrc00/updates.20180424.1145.gz
# Suspected BGP hijacking incidents involving ASN 16509:
#             prefix unauthorized_asns  frequency_of_suspected_hijacks
# 0  177.93.168.0/23          [263154]                               1
# 1  138.59.238.0/23          [263154]                               1
# 2  177.93.174.0/23          [263154]                               1
